# %%
import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


from nltk.corpus import stopwords

from tqdm import tqdm
import os
import nltk
import spacy
spacy.require_gpu()
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")

from bs4 import BeautifulSoup

from datetime import date

# %%
data_path = r"D:\covid research\output\step 2 output\2020-02-en"
days=os.listdir(data_path)
# days =[ i for i in days if i.split('.')[0].split('-')[-1]=='en']
print(days)
# Out:
# ['step2-output-EN-2020-02-01.csv', 'step2-output-EN-2020-02-04.csv', 'step2-output-EN-2020-02-05.csv', 'step2-output-EN-2020-02-06.csv', 'step2-output-EN-2020-02-09.csv', 'step2-output-EN-2020-02-10.csv', 'step2-output-EN-2020-02-11.csv', 'step2-output-EN-2020-02-14.csv', 'step2-output-EN-2020-02-16.csv', 'step2-output-EN-2020-02-17.csv', 'step2-output-EN-2020-02-20.csv', 'step2-output-EN-2020-02-21.csv', 'step2-output-EN-2020-02-22.csv', 'step2-output-EN-2020-02-27.csv', 'step2-output-EN-2020-02-29.csv']

# %%
data_list = []
for i in days:
    file_path  = i
    path = os.path.join(data_path, file_path)
    print(path)
    df_day = pd.read_csv(path,lineterminator='\n')
    data_list.append(df_day)

df = pd.concat(data_list)
# Out:
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-01.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-04.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-05.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-06.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-09.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-10.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-11.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-14.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-16.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-17.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-20.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-21.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-22.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-27.csv
# D:\covid research\output\step 2 output\2020-02-en\step2-output-EN-2020-02-29.csv

# %%
df_date = df.copy(deep=True)
df_date['day'] = df_date['created_at'].apply(lambda x: x.split(' ')[0])
df_date['hour'] = df_date['created_at'].apply(lambda x: x.split(' ')[1])
df_date['hour'] = df_date['hour'].apply(lambda x: x.split('-')[0])
#start_date = '2020-03-' + '%.2d' % start
#end_date = '2020-03-' + '%.2d' % (end + 1)

#selected_date = (df_date['day'] != start_date) & (df_date['day'] != end_date)
df_01 = df_date.copy(deep=True)
df_01 = df_01.reset_index(drop=True)
day_count = df_01.groupby('day').count()['text']

# %%
'''
hour_count = df_01.groupby(['day', 'hour']).count()['text']
hour_count_index = []
for i, j in list(hour_count.index):
    hour_count_index.append(i + '-' + j)
xticks_list = [] 
for i, (j, k) in enumerate(hour_count.index):
    if k =='00':
      xticks_list.append(hour_count_index[i])
xticks_list.append('2020-03-14-00')
    
'''
# Out:
# "\nhour_count = df_01.groupby(['day', 'hour']).count()['text']\nhour_count_index = []\nfor i, j in list(hour_count.index):\n    hour_count_index.append(i + '-' + j)\nxticks_list = [] \nfor i, (j, k) in enumerate(hour_count.index):\n    if k =='00':\n      xticks_list.append(hour_count_index[i])\nxticks_list.append('2020-03-14-00')\n    \n"

# %% [markdown]
# # Preprocessing

# %%
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
nlp = spacy.load('en_core_web_sm')

# %%
df_01['text'] = df_01['text'].apply(lambda x: remove_emoji(x))
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df_01['text'] = df_01['text'].apply(lambda x: BeautifulSoup(x, "html.parser").get_text())
df_01['text'] = df_01['text'].apply(lambda x: re.sub('\[[^]]*\]', '', x))
df_01['text'] = df_01['text'].apply(lambda x: re.sub(r'http\S+', '', x))
df_01['text'] = df_01['text'].str.replace('[^\w\s]','')
import nltk
nltk.download('stopwords')
stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
def remove_xml(text):
    return re.sub(r'<[^<]+?>', '', text)

def remove_newlines(text):
    return text.replace('\n', ' ') 
    

def remove_manyspaces(text):
    return re.sub(r'\s+', ' ', text)

def clean_text(text):
    text = remove_xml(text)
    text = remove_newlines(text)
    text = remove_manyspaces(text)
    return text
df_01['text']= df_01['text'].apply(clean_text)
df_02 = df_01.copy()
nlp = spacy.load('en_core_web_sm')
# lemmatizatioin using Spacy to count the appearance of each word
def space (comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df_02['text']= df_02['text'].apply(space)
df_02['text'].head(20)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0     rt inquirerdotnet break department health conf...
# 1                                       coronavirus may
# 2     rt earth_toheaven nomeat_nocoronavirus situati...
# 3     rt whophilippines 2 confirm 2019ncov case phil...
# 4     rt annnaadilli coronavirus uk murray score we ...
# 5     rt eviljohnsavage wtf either one sleazy virus ...
# 6     leslietim that s tad cynical especially give o...
# 7     nomeat_nocoronavirus read complete spiritual k...
# 8              bbc news coronavirus two case confirm uk
# 9     rt cnnphilippine break first report death due ...
# 10    rt khush_arthur coronavirus case mainland chin...
# 11    rt qtrresearch man boston recently return wuha...
# 12          rt relatehugots bore stay home also lazy go
# 13    rt be_nationalist charliechancat colorblind07 ...
# 14                        catch subway due corona virus
# 15    rt ekohotblog fg put place emergency response ...
# 16    rt amazonposition crazy many people inform cor...
# 17    rt disclosetv chinas huanggang city mayor say ...
# 18    wave apparently canada version corona virus st...
# 19    rt tomvalletti coronavirus train italy teenage...
# Name: text, dtype: object

# %% [markdown]
# # NRC

# %%
ncr = pd.read_excel("D:/covid research/src/local_exe/step 3/NRC-Emotion-Lexicon-v0.92-In105Languages-Nov2017Translations.xlsx")
ncr = ncr[['English (en)', 'Positive', 'Negative', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']]
emotions = ['Anger', 'Anticipation','Disgust','Fear', 'Joy','Sadness', 'Surprise', 'Trust']

def join_edited_string(edited_tweets):
    
    edited_string = ''
    for row in edited_tweets:
        edited_string = edited_string + ' ' + row
        
    return edited_string
joined_string = join_edited_string(df_01['text'])

tokens = joined_string.split(' ')

joined_string1 = join_edited_string(df_02['text'])
tokens1 = joined_string1.split(' ')

unique_words = set(tokens)
unique_words1 = set(tokens1)
unique_words.update(unique_words1)
word_to_ind = dict((word, i) for i, word in enumerate(unique_words))
ind_to_word = dict((i, word) for i, word in enumerate(unique_words))

# %%
import nltk
nltk.download('punkt')
from collections import defaultdict
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_tweets = df_01.copy(deep=True)
emo_info = {'emotion':'' , 'emo_frq': defaultdict(int) }
list_emotion_counts = []
for emotion in emotions:
        emo_info = {}
        emo_info['emotion'] = emotion
        emo_info['emo_frq'] = defaultdict(int)
        list_emotion_counts.append(emo_info)
nrow = df_tweets.shape[0]
df_emotions = pd.DataFrame(0, index=df_tweets.index, columns=emotions)

# %%
process_count=0
for i in range(nrow):
    
        process_count+=1
        if process_count % 100==0:
            print(process_count)
            print(df_tweets.loc[i])
        tweet = word_tokenize(df_tweets.loc[i]['text'])
        for word in tweet:
            word_stemmed = word
            result = ncr[ncr['English (en)'] == word_stemmed]
            if not result.empty:
                # update the tweet-emotions counts
                for idx, emotion in enumerate(emotions):
                    df_emotions.at[i, emotion] += result[emotion].iloc[0]
                    # update the frequencies dictionary list
                    if result[emotion].iloc[0].any():
                        try:
                            list_emotion_counts[idx]['emo_frq'][word_to_ind[word]] += 1
                        except:
                            continue
            else:
                doc = nlp(word)
                word_stemmed1 = " ".join([token.lemma_ for token in doc]).lower()
                result1 = ncr[ncr['English (en)'] == word_stemmed1]
                if not result1.empty:
                    # update the tweet-emotions counts
                    for idx, emotion in enumerate(emotions):
                        df_emotions.at[i, emotion] += result1[emotion].iloc[0]
                        # update the frequencies dictionary list
                        if result1[emotion].iloc[0].any():
                            try:
                                list_emotion_counts[idx]['emo_frq'][word_to_ind[word_stemmed1]] += 1
                            except:
                                continue
# Out:
# 100
# created_at                                      2020-02-02 01-33-18
# id_str                                          1223781406238658561
# text              rt lunarkjd ace cafe cancelled second protest ...
# user              {'id': 3139665878, 'id_str': '3139665878', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Parallel Universe
# country\r                                           united states\r
# day                                                      2020-02-02
# hour                                                             01
# Name: 99, dtype: object
# 200
# created_at                                      2020-02-02 03-55-31
# id_str                                          1223817196209467398
# text              rt shehzad_ind coronavirus dynasty would calle...
# user              {'id': 789967031831584768, 'id_str': '78996703...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    India🇮🇳
# country\r                                                   india\r
# day                                                      2020-02-02
# hour                                                             03
# Name: 199, dtype: object
# 300
# created_at                                      2020-02-01 18-38-41
# id_str                                          1223677064517079040
# text              rt raheemkassam john bolton may serious questi...
# user              {'id': 2440527318, 'id_str': '2440527318', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Portland, OR
# country\r                                           united states\r
# day                                                      2020-02-01
# hour                                                             18
# Name: 299, dtype: object
# 400
# created_at                                      2020-02-01 18-12-51
# id_str                                          1223670563366825984
# text              rt ani uttarakhand woman suspected infected co...
# user              {'id': 973658502358032385, 'id_str': '97365850...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Noida, India
# country\r                                                   india\r
# day                                                      2020-02-01
# hour                                                             18
# Name: 399, dtype: object
# 500
# created_at                                      2020-02-02 05-35-33
# id_str                                          1223842370422050816
# text              nomeat_nocoronavirus never kill animal make pe...
# user              {'id': 913287704208490496, 'id_str': '91328770...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Gurgaon, India
# country\r                                                   india\r
# day                                                      2020-02-02
# hour                                                             05
# Name: 499, dtype: object
# 600
# created_at                                      2020-02-01 19-51-03
# id_str                                          1223695276214452225
# text              edited rcmp media deny canadian connection sou...
# user              {'id': 2842929358, 'id_str': '2842929358', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                 Vancouver British Columbia
# country\r                                                  canada\r
# day                                                      2020-02-01
# hour                                                             19
# Name: 599, dtype: object
# 700
# created_at                                      2020-02-02 04-19-52
# id_str                                          1223823324092026882
# text              rt mohfw_india update novelcoronavirus second ...
# user              {'id': 955072886091345920, 'id_str': '95507288...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Kohima,  India
# country\r                                                   india\r
# day                                                      2020-02-02
# hour                                                             04
# Name: 699, dtype: object
# 800
# created_at                                      2020-02-02 05-27-38
# id_str                                          1223840378131898370
# text              rt satlokchannel eating meat sinful god ordere...
# user              {'id': 1124959377436188673, 'id_str': '1124959...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Gujarat, India
# country\r                                                   india\r
# day                                                      2020-02-02
# hour                                                             05
# Name: 799, dtype: object
# 900
# created_at                                      2020-02-01 13-06-27
# id_str                                          1223593455277883392
# text              rt drtedros working closely countries control ...
# user              {'id': 1158048460689424384, 'id_str': '1158048...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                               陰キャ、引用ＲＴ、スクショ、🚷右も左も排他主義も即ブロ💢
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             13
# Name: 899, dtype: object
# 1000
# created_at                                      2020-02-01 15-27-26
# id_str                                          1223628934903812098
# text              rt smartnewsroom public service advisory help ...
# user              {'id': 414798702, 'id_str': '414798702', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     manila
# country\r                                             philippines\r
# day                                                      2020-02-01
# hour                                                             15
# Name: 999, dtype: object
# 1100
# created_at                                      2020-02-02 02-15-26
# id_str                                          1223792009418285056
# text              rt tomvalletti coronavirus train italy teenage...
# user              {'id': 21628666, 'id_str': '21628666', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Ottawa, ON, Canada
# country\r                                                  canada\r
# day                                                      2020-02-02
# hour                                                             02
# Name: 1099, dtype: object
# 1200
# created_at                                      2020-02-01 14-35-39
# id_str                                          1223615903193014272
# text              rt yogifreespirit coronavirus blanket term var...
# user              {'id': 251735706, 'id_str': '251735706', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    jupiter
# country\r                                           united states\r
# day                                                      2020-02-01
# hour                                                             14
# Name: 1199, dtype: object
# 1300
# created_at                                      2020-02-01 15-17-35
# id_str                                          1223626456049364995
# text              rt anjum_fan good news infected patient fully ...
# user              {'id': 1158588658498375680, 'id_str': '1158588...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                   Swapdoodle, Nintendo 3DS
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             15
# Name: 1299, dtype: object
# 1400
# created_at                                      2020-02-01 19-03-00
# id_str                                          1223683184019353602
# text              rt gina4trump massachusetts man coronavirus st...
# user              {'id': 823308721686093825, 'id_str': '82330872...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Minot, ND
# country\r                                           united states\r
# day                                                      2020-02-01
# hour                                                             19
# Name: 1399, dtype: object
# 1500
# created_at                                      2020-02-01 16-21-22
# id_str                                          1223642507667550209
# text              funny would wish coronavirus anyone people hig...
# user              {'id': 757835914437545984, 'id_str': '75783591...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             United Kingdom
# country\r                                          united kingdom\r
# day                                                      2020-02-01
# hour                                                             16
# Name: 1499, dtype: object
# 1600
# created_at                                      2020-02-02 06-15-45
# id_str                                          1223852487116914688
# text                                      kattrinbee must wear mask
# user              {'id': 3840506775, 'id_str': '3840506775', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Washington, USA
# country\r                                           united states\r
# day                                                      2020-02-02
# hour                                                             06
# Name: 1599, dtype: object
# 1700
# created_at                                      2020-02-01 12-18-48
# id_str                                          1223581463771107328
# text              rt ncov19 coronavirus infected people 10 days ...
# user              {'id': 1097766848777543680, 'id_str': '1097766...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Birbdom
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             12
# Name: 1699, dtype: object
# 1800
# created_at                                      2020-02-01 22-09-06
# id_str                                          1223730017630400513
# text              yikes lessons public health hope rest world ta...
# user              {'id': 35109690, 'id_str': '35109690', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Rochester, MN
# country\r                                           united states\r
# day                                                      2020-02-01
# hour                                                             22
# Name: 1799, dtype: object
# 1900
# created_at                                      2020-02-01 15-41-20
# id_str                                          1223632432936538113
# text                                  thean1meman corona chan guess
# user              {'id': 810201960368533504, 'id_str': '81020196...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Färjestaden
# country\r                                                 sverige\r
# day                                                      2020-02-01
# hour                                                             15
# Name: 1899, dtype: object
# 2000
# created_at                                      2020-02-01 11-32-53
# id_str                                          1223569908459429888
# text              rt mayapark28 connectbtsbuenosaires thank comi...
# user              {'id': 406868698, 'id_str': '406868698', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                rock bottom
# country\r                                           united states\r
# day                                                      2020-02-01
# hour                                                             11
# Name: 1999, dtype: object
# 2100
# created_at                                      2020-02-02 03-23-12
# id_str                                          1223809063470948352
# text              rt cnnbrk man boston recently returned wuhan c...
# user              {'id': 73736607, 'id_str': '73736607', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Pittsburgh, PA USA
# country\r                                           united states\r
# day                                                      2020-02-02
# hour                                                             03
# Name: 2099, dtype: object
# 2200
# created_at                                      2020-02-02 04-20-41
# id_str                                          1223823529612730370
# text              rt imdipendraji nomeat_nocoronavirus quit eati...
# user              {'id': 865122283173666819, 'id_str': '86512228...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               कुरूक्षेत्र
# country\r                                                   india\r
# day                                                      2020-02-02
# hour                                                             04
# Name: 2199, dtype: object
# 2300
# created_at                                      2020-02-01 14-42-03
# id_str                                          1223617513793081344
# text              rt _abiddulph canada wont follow us declare na...
# user              {'id': 3948881354, 'id_str': '3948881354', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Comox, British Columbia
# country\r                                                  canada\r
# day                                                      2020-02-01
# hour                                                             14
# Name: 2299, dtype: object
# 2400
# created_at                                      2020-02-01 17-22-04
# id_str                                          1223657783314219011
# text              rt michael_k_farr take farrcast weekend week t...
# user              {'id': 18145104, 'id_str': '18145104', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Washington, D.C.
# country\r                                           united states\r
# day                                                      2020-02-01
# hour                                                             17
# Name: 2399, dtype: object
# 2500
# created_at                                      2020-02-02 06-41-45
# id_str                                          1223859030205976576
# text              rt 1ahirwar nomeat_nocoronavirus eating meat s...
# user              {'id': 2914336148, 'id_str': '2914336148', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      India
# country\r                                                   india\r
# day                                                      2020-02-02
# hour                                                             06
# Name: 2499, dtype: object
# 2600
# created_at                                      2020-02-02 06-43-21
# id_str                                          1223859432850960386
# text              rt praveen21210080 nomeat_nocoronavirus little...
# user              {'id': 3315553340, 'id_str': '3315553340', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Nizampur, New Delhi
# country\r                                                   india\r
# day                                                      2020-02-02
# hour                                                             06
# Name: 2599, dtype: object
# 2700
# created_at                                      2020-02-01 08-34-08
# id_str                                          1223524924561788932
# text              rt dakekang wuhan soldiers week two lockdown p...
# user              {'id': 29790783, 'id_str': '29790783', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Poland
# country\r                                                  polska\r
# day                                                      2020-02-01
# hour                                                             08
# Name: 2699, dtype: object
# 2800
# created_at                                      2020-02-02 06-36-29
# id_str                                          1223857704826916865
# text              rt satyug20201 nomeat_nocoronavirus according ...
# user              {'id': 1212672404750626816, 'id_str': '1212672...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               उदयपुर, भारत
# country\r                                                   india\r
# day                                                      2020-02-02
# hour                                                             06
# Name: 2799, dtype: object
# 2900
# created_at                                      2020-02-01 07-47-12
# id_str                                          1223513113376387079
# text              rt chayraestillore corona virus giving serious...
# user              {'id': 1176629310616043520, 'id_str': '1176629...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  earl city
# country\r                                                  canada\r
# day                                                      2020-02-01
# hour                                                             07
# Name: 2899, dtype: object
# 3000
# created_at                                      2020-02-01 21-42-35
# id_str                                          1223723344500944896
# text              epidemic vs pandemic ebola epidemic disease me...
# user              {'id': 706146600, 'id_str': '706146600', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       Colorado Springs, CO
# country\r                                           united states\r
# day                                                      2020-02-01
# hour                                                             21
# Name: 2999, dtype: object
# 3100
# created_at                                      2020-02-01 16-04-37
# id_str                                          1223638292387598336
# text              corona virus isnt excuse racist fellow asians ...
# user              {'id': 987655659943477248, 'id_str': '98765565...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                Republic of the Philippines
# country\r                                             philippines\r
# day                                                      2020-02-01
# hour                                                             16
# Name: 3099, dtype: object
# 3200
# created_at                                      2020-02-01 11-57-53
# id_str                                          1223576199928143875
# text              rt twittermoments health officials toronto ann...
# user              {'id': 144655110, 'id_str': '144655110', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   scotland
# country\r                                          united kingdom\r
# day                                                      2020-02-01
# hour                                                             11
# Name: 3199, dtype: object
# 3300
# created_at                                      2020-02-02 01-53-27
# id_str                                          1223786477139714048
# text              rt echinanews 2590 new confirmed cases novel c...
# user              {'id': 36877205, 'id_str': '36877205', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Tehran
# country\r                                                   ایران\r
# day                                                      2020-02-02
# hour                                                             01
# Name: 3299, dtype: object
# 3400
# created_at                                      2020-02-01 11-11-50
# id_str                                          1223564611057786881
# text                                    letsbeatcoronatogether sign
# user              {'id': 1160171138636492800, 'id_str': '1160171...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Makkah KSA.
# country\r                                                السعودية\r
# day                                                      2020-02-01
# hour                                                             11
# Name: 3399, dtype: object
# 3500
# created_at                                      2020-02-02 00-36-18
# id_str                                          1223767061693747200
# text              rt joeclews_ driver looks absolutely thrilled ...
# user              {'id': 400619147, 'id_str': '400619147', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              The Milky Way
# country\r                                               nederland\r
# day                                                      2020-02-02
# hour                                                             00
# Name: 3499, dtype: object
# 3600
# created_at                                      2020-02-01 19-32-27
# id_str                                          1223690595354513410
# text              rt mushaimm letsbeatcoronatogether till end ma...
# user              {'id': 1127185022065180672, 'id_str': '1127185...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Karachi, Naya Pakistan
# country\r                                                 پاکستان\r
# day                                                      2020-02-01
# hour                                                             19
# Name: 3599, dtype: object
# 3700
# created_at                                      2020-02-01 07-51-20
# id_str                                          1223514153555378176
# text              rt drtedros google launches sos alert coronavi...
# user              {'id': 910317124727353344, 'id_str': '91031712...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Timor-Leste
# country\r                            timór lorosa'e / timor-leste\r
# day                                                      2020-02-01
# hour                                                             07
# Name: 3699, dtype: object
# 3800
# created_at                                      2020-02-01 21-26-44
# id_str                                          1223719355718033412
# text              rt theanfieldwrap honest god thing stop reds f...
# user              {'id': 149039540, 'id_str': '149039540', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          België | Tanzania
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             21
# Name: 3799, dtype: object
# 3900
# created_at                                      2020-02-01 12-40-17
# id_str                                          1223586870220726274
# text              rt renukajain6 dear investors today market fal...
# user              {'id': 1064858820915154944, 'id_str': '1064858...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                ગરવી ગુજરાત
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             12
# Name: 3899, dtype: object
# 4000
# created_at                                      2020-02-04 20-05-03
# id_str                                          1224785963030843402
# text              rt nypost coronavirus patient went mexico city...
# user              {'id': 116373042, 'id_str': '116373042', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Lordran
# country\r                                                       -\r
# day                                                      2020-02-04
# hour                                                             20
# Name: 3999, dtype: object
# 4100
# created_at                                      2020-02-04 15-04-44
# id_str                                          1224710385867067398
# text              rt mushahad_naeem turkey sent medical aid chin...
# user              {'id': 1522702807, 'id_str': '1522702807', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Kaduna, Nigeria
# country\r                                                 nigeria\r
# day                                                      2020-02-04
# hour                                                             15
# Name: 4099, dtype: object
# 4200
# created_at                                      2020-02-05 06-11-56
# id_str                                          1224938690218082304
# text              rt giasison february 5 time stamp 1353h corona...
# user              {'id': 1207125709329559552, 'id_str': '1207125...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                             Lungsod ng Mandaluyong, Pamban
# country\r                                                       -\r
# day                                                      2020-02-05
# hour                                                             06
# Name: 4199, dtype: object
# 4300
# created_at                                      2020-02-05 03-20-23
# id_str                                          1224895518217842688
# text              rt coronavirusflu breaking news nightmare crui...
# user              {'id': 1090595536183414784, 'id_str': '1090595...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                        USA
# country\r                                           united states\r
# day                                                      2020-02-05
# hour                                                             03
# Name: 4299, dtype: object
# 4400
# created_at                                      2020-02-05 06-34-55
# id_str                                          1224944474142466049
# text              rt preparecenter world worried coronavirus rig...
# user              {'id': 38027006, 'id_str': '38027006', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Geneva, Switzerland
# country\r                          schweiz/suisse/svizzera/svizra\r
# day                                                      2020-02-05
# hour                                                             06
# Name: 4399, dtype: object
# 4500
# created_at                                      2020-02-04 18-39-03
# id_str                                          1224764320384417792
# text              rt dmon4ever wuhancoronavirus update korean wo...
# user              {'id': 1046435615900930049, 'id_str': '1046435...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              United States
# country\r                                           united states\r
# day                                                      2020-02-04
# hour                                                             18
# Name: 4499, dtype: object
# 4600
# created_at                                      2020-02-04 17-42-08
# id_str                                          1224749996874125312
# text              tracybrabin interesting many people clutch pea...
# user              {'id': 49934502, 'id_str': '49934502', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Chorley, Lancashire
# country\r                                          united kingdom\r
# day                                                      2020-02-04
# hour                                                             17
# Name: 4599, dtype: object
# 4700
# created_at                                      2020-02-04 13-36-27
# id_str                                          1224688168638742528
# text              rt tanzeel_akhtar macau shuts casinos amid cor...
# user              {'id': 176108852, 'id_str': '176108852', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            On the move ...
# country\r                                          united kingdom\r
# day                                                      2020-02-04
# hour                                                             13
# Name: 4699, dtype: object
# 4800
# created_at                                      2020-02-04 13-05-01
# id_str                                          1224680258164678656
# text              arianna_emery im sure well make breed variants...
# user              {'id': 1070506170836807680, 'id_str': '1070506...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Massachusetts, USA
# country\r                                           united states\r
# day                                                      2020-02-04
# hour                                                             13
# Name: 4799, dtype: object
# 4900
# created_at                                      2020-02-04 19-21-40
# id_str                                          1224775045240819713
# text              rt essenviews trump says coronavirus good endi...
# user              {'id': 32724987, 'id_str': '32724987', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Atlanta, GA
# country\r                                           united states\r
# day                                                      2020-02-04
# hour                                                             19
# Name: 4899, dtype: object
# 5000
# created_at                                      2020-02-04 09-33-43
# id_str                                          1224627082787020800
# text              rt ashindestad im longer worried coronavirus l...
# user              {'id': 276160895, 'id_str': '276160895', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Topanga, CA
# country\r                                           united states\r
# day                                                      2020-02-04
# hour                                                             09
# Name: 4999, dtype: object
# 5100
# created_at                                      2020-02-04 19-07-09
# id_str                                          1224771392010358787
# text              rt maaba_g corona virus doesnt give excuse rac...
# user              {'id': 1915068320, 'id_str': '1915068320', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Whitby, Ontario
# country\r                                                  canada\r
# day                                                      2020-02-04
# hour                                                             19
# Name: 5099, dtype: object
# 5200
# created_at                                      2020-02-04 21-37-21
# id_str                                          1224809191077867520
# text              rt eha_news china converts gymnasiums exhibiti...
# user              {'id': 349445673, 'id_str': '349445673', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Earth
# country\r                                           united states\r
# day                                                      2020-02-04
# hour                                                             21
# Name: 5199, dtype: object
# 5300
# created_at                                      2020-02-05 02-24-54
# id_str                                          1224881555388215296
# text              rt buzzman888 china coronavirus really think t...
# user              {'id': 750377949065535488, 'id_str': '75037794...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Ohio, USA
# country\r                                           united states\r
# day                                                      2020-02-05
# hour                                                             02
# Name: 5299, dtype: object
# 5400
# created_at                                      2020-02-04 22-51-55
# id_str                                          1224827956394176512
# text              rt zerohedgenew2 fires erupting coronavirus qu...
# user              {'id': 887169684784766977, 'id_str': '88716968...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              United States
# country\r                                           united states\r
# day                                                      2020-02-04
# hour                                                             22
# Name: 5399, dtype: object
# 5500
# created_at                                      2020-02-04 15-33-44
# id_str                                          1224717683939250182
# text              bill gates next outbreak ready via youtube cor...
# user              {'id': 82013789, 'id_str': '82013789', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              United States
# country\r                                           united states\r
# day                                                      2020-02-04
# hour                                                             15
# Name: 5499, dtype: object
# 5600
# created_at                                      2020-02-05 02-24-57
# id_str                                          1224881567975104512
# text              rt cnn museums forced temporarily close doors ...
# user              {'id': 992890858339905537, 'id_str': '99289085...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            California, USA
# country\r                                           united states\r
# day                                                      2020-02-05
# hour                                                             02
# Name: 5599, dtype: object
# 5700
# created_at                                      2020-02-04 10-24-18
# id_str                                          1224639812470280192
# text              rt cnbc garlic wont protect coronavirus pushes...
# user              {'id': 27338119, 'id_str': '27338119', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# ...
# text              rt howroute drivethru coronavirus testing cent...
# user              {'id': 4534138094, 'id_str': '4534138094', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Pacific Northwest
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             15
# Name: 48799, dtype: object
# 48900
# created_at                                      2020-02-29 17-05-09
# id_str                                          1233800386319986690
# text              rt simongerman600 map shows big impact quarant...
# user              {'id': 282285145, 'id_str': '282285145', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Lohja, Suomi
# country\r                                         suomi / finland\r
# day                                                      2020-02-29
# hour                                                             17
# Name: 48899, dtype: object
# 49000
# created_at                                      2020-02-29 18-44-27
# id_str                                          1233825375983149060
# text              rt business us reported first death coronaviru...
# user              {'id': 2525314328, 'id_str': '2525314328', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              United States
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             18
# Name: 48999, dtype: object
# 49100
# created_at                                      2020-02-29 10-14-21
# id_str                                          1233697005123358721
# text              coronavirus means 2020 geneva motor show cance...
# user              {'id': 61132876, 'id_str': '61132876', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Herts, UK
# country\r                                          united kingdom\r
# day                                                      2020-02-29
# hour                                                             10
# Name: 49099, dtype: object
# 49200
# created_at                                      2020-02-29 20-21-05
# id_str                                          1233849694582956036
# text              rt yahoonews trump rapidly developing vaccine ...
# user              {'id': 171762903, 'id_str': '171762903', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Charleston, SC
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             20
# Name: 49199, dtype: object
# 49300
# created_at                                      2020-02-29 13-48-12
# id_str                                          1233750822246285314
# text              rt hresistanz johnlundin breaking trump called...
# user              {'id': 16548855, 'id_str': '16548855', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                 La Sierra Nevada, Colombia
# country\r                                                       -\r
# day                                                      2020-02-29
# hour                                                             13
# Name: 49299, dtype: object
# 49400
# created_at                                      2020-02-29 18-55-22
# id_str                                          1233828123277430785
# text              rt wadepthealth new information emerges across...
# user              {'id': 1154589042, 'id_str': '1154589042', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Chicago
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             18
# Name: 49399, dtype: object
# 49500
# created_at                                      2020-02-29 11-42-43
# id_str                                          1233719243327315968
# text              rt danrather pres trump calls coronavirus dems...
# user              {'id': 2826410182, 'id_str': '2826410182', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              United States
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             11
# Name: 49499, dtype: object
# 49600
# created_at                                      2020-03-01 04-13-34
# id_str                                          1233968598898659329
# text              rt charliekirk11 breaking first two cases coro...
# user              {'id': 821858861330022400, 'id_str': '82185886...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Mount Ayr, Iowa
# country\r                                           united states\r
# day                                                      2020-03-01
# hour                                                             04
# Name: 49599, dtype: object
# 49700
# created_at                                      2020-02-29 23-40-01
# id_str                                          1233899757770354689
# text              rt wordswithsteph trump reluctantly admits out...
# user              {'id': 815871284, 'id_str': '815871284', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Florida, USA
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             23
# Name: 49699, dtype: object
# 49800
# created_at                                      2020-02-29 11-34-34
# id_str                                          1233717192295899137
# text              dr peter lin best explanation coronavirus via ...
# user              {'id': 1175321407, 'id_str': '1175321407', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Osgoode,On
# country\r                                                  canada\r
# day                                                      2020-02-29
# hour                                                             11
# Name: 49799, dtype: object
# 49900
# created_at                                      2020-02-29 19-40-13
# id_str                                          1233839410149498884
# text                                             johannacoronaa god
# user              {'id': 451313129, 'id_str': '451313129', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Long Beach, CA
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             19
# Name: 49899, dtype: object
# 50000
# created_at                                      2020-02-29 23-54-54
# id_str                                          1233903503283752960
# text              rt rokhanna coronavirus shows importance berni...
# user              {'id': 381722036, 'id_str': '381722036', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            North Carolina
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             23
# Name: 49999, dtype: object
# 50100
# created_at                                      2020-02-29 16-57-50
# id_str                                          1233798545045671938
# text              rt templestream realdonaldtrump 1 1 person die...
# user              {'id': 122275614, 'id_str': '122275614', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Ohio, USA
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             16
# Name: 50099, dtype: object
# 50200
# created_at                                      2020-02-29 20-33-03
# id_str                                          1233852706089029633
# text              hillary already killed least many americans ye...
# user              {'id': 4104950054, 'id_str': '4104950054', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Wisconsin, USA
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             20
# Name: 50199, dtype: object
# 50300
# created_at                                      2020-02-29 17-58-41
# id_str                                          1233813858432749570
# text                       hope coronavirus scares people like away
# user              {'id': 2254578021, 'id_str': '2254578021', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                        Bed
# country\r                                                  россия\r
# day                                                      2020-02-29
# hour                                                             17
# Name: 50299, dtype: object
# 50400
# created_at                                      2020-02-29 16-06-46
# id_str                                          1233785693689860097
# text              rt codemonkeyz japanese biodata team discovere...
# user              {'id': 712722550669770752, 'id_str': '71272255...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Texas, USA
# country\r                                           united states\r
# day                                                      2020-02-29
# hour                                                             16
# Name: 50399, dtype: object
# 50500
# created_at                                      2020-03-01 03-55-49
# id_str                                          1233964131947925504
# text              choices 2 3 hair phone im totally getting covid19
# user              {'id': 20611428, 'id_str': '20611428', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                     Sherwood Park, Alberta
# country\r                                                  canada\r
# day                                                      2020-03-01
# hour                                                             03
# Name: 50499, dtype: object
# 50600
# created_at                                      2020-02-29 16-46-09
# id_str                                          1233795604821823488
# text              milans salone del mobile furniture fair postpo...
# user              {'id': 21873058, 'id_str': '21873058', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                     Everywhere And Nowhere
# country\r                                                       -\r
# day                                                      2020-02-29
# hour                                                             16
# Name: 50599, dtype: object

# %%
df_tweets = pd.concat([df_tweets, df_emotions], axis=1)

# %%
df_tweets.to_csv(r"D:\covid research\output\step 3 output\2020-02-EN.csv")
