# %%
import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


from nltk.corpus import stopwords

from tqdm import tqdm
import os
import nltk
import spacy
spacy.require_gpu()
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")

from bs4 import BeautifulSoup

from datetime import date
# Out:
# c:\Users\hydro\anaconda3\envs\cov\lib\site-packages\cupy\_environment.py:205: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(

# %%
data_path = r"D:\covid research\output\step 2 output\2020-06-en"
days=os.listdir(data_path)
# days =[ i for i in days if i.split('.')[0].split('-')[-1]=='en']
print(days)
# Out:
# ['step2-output-EN-2020-06-01.csv', 'step2-output-EN-2020-06-02.csv', 'step2-output-EN-2020-06-04.csv', 'step2-output-EN-2020-06-05.csv', 'step2-output-EN-2020-06-06.csv', 'step2-output-EN-2020-06-07.csv', 'step2-output-EN-2020-06-08.csv', 'step2-output-EN-2020-06-09.csv', 'step2-output-EN-2020-06-10.csv', 'step2-output-EN-2020-06-11.csv', 'step2-output-EN-2020-06-12.csv', 'step2-output-EN-2020-06-13.csv', 'step2-output-EN-2020-06-14.csv', 'step2-output-EN-2020-06-15.csv', 'step2-output-EN-2020-06-16.csv', 'step2-output-EN-2020-06-17.csv', 'step2-output-EN-2020-06-18.csv', 'step2-output-EN-2020-06-19.csv', 'step2-output-EN-2020-06-20.csv', 'step2-output-EN-2020-06-21.csv', 'step2-output-EN-2020-06-22.csv', 'step2-output-EN-2020-06-23.csv', 'step2-output-EN-2020-06-24.csv', 'step2-output-EN-2020-06-25.csv', 'step2-output-EN-2020-06-26.csv', 'step2-output-EN-2020-06-27.csv', 'step2-output-EN-2020-06-28.csv', 'step2-output-EN-2020-06-29.csv', 'step2-output-EN-2020-06-30.csv']

# %%
data_list = []
for i in days:
    file_path  = i
    path = os.path.join(data_path, file_path)
    print(path)
    df_day = pd.read_csv(path,lineterminator='\n')
    data_list.append(df_day)

df = pd.concat(data_list)
# Out:
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-01.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-02.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-04.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-05.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-06.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-07.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-08.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-09.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-10.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-11.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-12.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-13.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-14.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-15.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-16.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-17.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-18.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-19.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-20.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-21.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-22.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-23.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-24.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-25.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-26.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-27.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-28.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-29.csv
# D:\covid research\output\step 2 output\2020-06-en\step2-output-EN-2020-06-30.csv

# %%
df_date = df.copy(deep=True)
df_date['day'] = df_date['created_at'].apply(lambda x: x.split(' ')[0])
df_date['hour'] = df_date['created_at'].apply(lambda x: x.split(' ')[1])
df_date['hour'] = df_date['hour'].apply(lambda x: x.split('-')[0])
#start_date = '2020-03-' + '%.2d' % start
#end_date = '2020-03-' + '%.2d' % (end + 1)

#selected_date = (df_date['day'] != start_date) & (df_date['day'] != end_date)
df_01 = df_date.copy(deep=True)
df_01 = df_01.reset_index(drop=True)
day_count = df_01.groupby('day').count()['text']

# %%
'''
hour_count = df_01.groupby(['day', 'hour']).count()['text']
hour_count_index = []
for i, j in list(hour_count.index):
    hour_count_index.append(i + '-' + j)
xticks_list = [] 
for i, (j, k) in enumerate(hour_count.index):
    if k =='00':
      xticks_list.append(hour_count_index[i])
xticks_list.append('2020-03-14-00')
    
'''
# Out:
# "\nhour_count = df_01.groupby(['day', 'hour']).count()['text']\nhour_count_index = []\nfor i, j in list(hour_count.index):\n    hour_count_index.append(i + '-' + j)\nxticks_list = [] \nfor i, (j, k) in enumerate(hour_count.index):\n    if k =='00':\n      xticks_list.append(hour_count_index[i])\nxticks_list.append('2020-03-14-00')\n    \n"

# %% [markdown]
# # Preprocessing

# %%
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
nlp = spacy.load('en_core_web_sm')

# %%
df_01['text'] = df_01['text'].apply(lambda x: remove_emoji(x))
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df_01['text'] = df_01['text'].apply(lambda x: BeautifulSoup(x, "html.parser").get_text())
df_01['text'] = df_01['text'].apply(lambda x: re.sub('\[[^]]*\]', '', x))
df_01['text'] = df_01['text'].apply(lambda x: re.sub(r'http\S+', '', x))
df_01['text'] = df_01['text'].str.replace('[^\w\s]','')
import nltk
nltk.download('stopwords')
stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
def remove_xml(text):
    return re.sub(r'<[^<]+?>', '', text)

def remove_newlines(text):
    return text.replace('\n', ' ') 
    

def remove_manyspaces(text):
    return re.sub(r'\s+', ' ', text)

def clean_text(text):
    text = remove_xml(text)
    text = remove_newlines(text)
    text = remove_manyspaces(text)
    return text
df_01['text']= df_01['text'].apply(clean_text)
df_02 = df_01.copy()
nlp = spacy.load('en_core_web_sm')
# lemmatizatioin using Spacy to count the appearance of each word
def space (comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df_02['text']= df_02['text'].apply(space)
df_02['text'].head(20)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0     rt emilia_suze rexglacer shaquilleordea1 cbcal...
# 1     british regulator enlist 8 insurer pandemic te...
# 2     rt matthewacherry take month figure testing ce...
# 3     rt gingermarauder sikora bbcbreakfast relevant...
# 4                   university never coronavirus crisis
# 5     rt mrjamesob johnson darkest hour decision ess...
# 6     lamontfrazier4 imagine covid19 threat million ...
# 7     rt dandrezner pandemic end sight 40 million am...
# 8     rt dmrider city torontos covid19 briefing star...
# 9     worldwide coronavirus outbreak quarantine inte...
# 10    rt cjwerleman doctor public hospital kanpur in...
# 11    rt necrosofty we can not organize testing cent...
# 12    egodaddy lalabehr mattwolke u keep along trump...
# 13    derrickberthel1 markbishopuk think would agree...
# 14    coronation street star sam aston reveal expect...
# 15    rt delhi_sarcasm accord lady muslim should not...
# 16    rt govuk coronavirus wash hand regularly 20 se...
# 17    rt pmjamilla two month government simply use l...
# 18    rt yungtraplvrds nyc epicenter pandemic month ...
# 19    rt thehopper7 appeal labour mps stand regard r...
# Name: text, dtype: object

# %% [markdown]
# # NRC

# %%
ncr = pd.read_excel("D:/covid research/src/local_exe/step 3/NRC-Emotion-Lexicon-v0.92-In105Languages-Nov2017Translations.xlsx")
ncr = ncr[['English (en)', 'Positive', 'Negative', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']]
emotions = ['Anger', 'Anticipation','Disgust','Fear', 'Joy','Sadness', 'Surprise', 'Trust']

def join_edited_string(edited_tweets):
    
    edited_string = ''
    for row in edited_tweets:
        edited_string = edited_string + ' ' + row
        
    return edited_string
joined_string = join_edited_string(df_01['text'])

tokens = joined_string.split(' ')

joined_string1 = join_edited_string(df_02['text'])
tokens1 = joined_string1.split(' ')

unique_words = set(tokens)
unique_words1 = set(tokens1)
unique_words.update(unique_words1)
word_to_ind = dict((word, i) for i, word in enumerate(unique_words))
ind_to_word = dict((i, word) for i, word in enumerate(unique_words))

# %%
import nltk
nltk.download('punkt')
from collections import defaultdict
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_tweets = df_01.copy(deep=True)
emo_info = {'emotion':'' , 'emo_frq': defaultdict(int) }
list_emotion_counts = []
for emotion in emotions:
        emo_info = {}
        emo_info['emotion'] = emotion
        emo_info['emo_frq'] = defaultdict(int)
        list_emotion_counts.append(emo_info)
nrow = df_tweets.shape[0]
df_emotions = pd.DataFrame(0, index=df_tweets.index, columns=emotions)

# %%
process_count=0
for i in range(nrow):
    
        process_count+=1
        if process_count % 100==0:
            print(process_count)
            print(df_tweets.loc[i])
        tweet = word_tokenize(df_tweets.loc[i]['text'])
        for word in tweet:
            word_stemmed = word
            result = ncr[ncr['English (en)'] == word_stemmed]
            if not result.empty:
                # update the tweet-emotions counts
                for idx, emotion in enumerate(emotions):
                    df_emotions.at[i, emotion] += result[emotion].iloc[0]
                    # update the frequencies dictionary list
                    if result[emotion].iloc[0].any():
                        try:
                            list_emotion_counts[idx]['emo_frq'][word_to_ind[word]] += 1
                        except:
                            continue
            else:
                doc = nlp(word)
                word_stemmed1 = " ".join([token.lemma_ for token in doc]).lower()
                result1 = ncr[ncr['English (en)'] == word_stemmed1]
                if not result1.empty:
                    # update the tweet-emotions counts
                    for idx, emotion in enumerate(emotions):
                        df_emotions.at[i, emotion] += result1[emotion].iloc[0]
                        # update the frequencies dictionary list
                        if result1[emotion].iloc[0].any():
                            try:
                                list_emotion_counts[idx]['emo_frq'][word_to_ind[word_stemmed1]] += 1
                            except:
                                continue
# Out:
# 100
# created_at                                      2020-06-01 15-36-51
# id_str                                          1267480236423331844
# text              rt fvrnandaa donald trump called mexicans rapi...
# user              {'id': 2369958089, 'id_str': '2369958089', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Miami, FL
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             15
# Name: 99, dtype: object
# 200
# created_at                                      2020-06-01 16-25-32
# id_str                                          1267492487985274880
# text              rt iramakhanpk mask better ventilator home bet...
# user              {'id': 3389103919, 'id_str': '3389103919', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Islamabad
# country\r                                                 پاکستان\r
# day                                                      2020-06-01
# hour                                                             16
# Name: 199, dtype: object
# 300
# created_at                                      2020-06-01 17-27-26
# id_str                                          1267508065605206018
# text              rt kiritsomaiya met family police constable di...
# user              {'id': 1131802953440874497, 'id_str': '1131802...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Mumbai, India
# country\r                                                   india\r
# day                                                      2020-06-01
# hour                                                             17
# Name: 299, dtype: object
# 400
# created_at                                      2020-06-01 10-57-46
# id_str                                          1267410002781917185
# text              rt the_angeldevil waiting anonymous say corona...
# user              {'id': 1036285667087671299, 'id_str': '1036285...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     heaven
# country\r                                          united kingdom\r
# day                                                      2020-06-01
# hour                                                             10
# Name: 399, dtype: object
# 500
# created_at                                      2020-06-02 02-55-34
# id_str                                          1267651041052356610
# text                                rt exjon thankful covid19 cured
# user              {'id': 1619446226, 'id_str': '1619446226', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Washington, USA
# country\r                                           united states\r
# day                                                      2020-06-02
# hour                                                             02
# Name: 499, dtype: object
# 600
# created_at                                      2020-06-02 04-43-16
# id_str                                          1267678144636563456
# text              rt stillgray noticed media longer seems concer...
# user              {'id': 1240034628121038849, 'id_str': '1240034...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                             Liberty Prime(San Antonio, TX)
# country\r                                                       -\r
# day                                                      2020-06-02
# hour                                                             04
# Name: 599, dtype: object
# 700
# created_at                                      2020-06-01 21-03-47
# id_str                                          1267562511894798340
# text              rt ayamai give online learning upgrade covid19...
# user              {'id': 17835438, 'id_str': '17835438', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                         UK
# country\r                                          united kingdom\r
# day                                                      2020-06-01
# hour                                                             21
# Name: 699, dtype: object
# 800
# created_at                                      2020-06-01 12-10-24
# id_str                                          1267428281579601920
# text              rt lexartistes attending protests everyone tha...
# user              {'id': 25884318, 'id_str': '25884318', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   Hogwarts
# country\r                                                   kenya\r
# day                                                      2020-06-01
# hour                                                             12
# Name: 799, dtype: object
# 900
# created_at                                      2020-06-01 19-32-54
# id_str                                          1267539640346533889
# text              rt ctdata uscensusbureaus pulse survey may 141...
# user              {'id': 13329732, 'id_str': '13329732', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  new haven
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             19
# Name: 899, dtype: object
# 1000
# created_at                                      2020-06-01 13-35-08
# id_str                                          1267449605425262592
# text              rt cjwerleman doctor public hospital kanpur in...
# user              {'id': 774167577807294464, 'id_str': '77416757...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Banana Republic
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             13
# Name: 999, dtype: object
# 1100
# created_at                                      2020-06-01 14-01-01
# id_str                                          1267456119150186499
# text              rt karijoys weareinthistogether joytrain joy k...
# user              {'id': 1656891612, 'id_str': '1656891612', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                        USA
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             14
# Name: 1099, dtype: object
# 1200
# created_at                                      2020-06-01 21-52-16
# id_str                                          1267574713116692489
# text              rt fox2news monday numbers state reports 25 de...
# user              {'id': 1014134622316388354, 'id_str': '1014134...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Detroit, MI
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             21
# Name: 1199, dtype: object
# 1300
# created_at                                      2020-06-01 15-05-02
# id_str                                          1267472229476044801
# text                   rt alfredlewislll aint enforce like pandemic
# user              {'id': 755205993450078208, 'id_str': '75520599...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Fort Lauderdale, FL
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             15
# Name: 1299, dtype: object
# 1400
# created_at                                      2020-06-01 08-46-40
# id_str                                          1267377010395013121
# text                             together fight covid19nigeria rape
# user              {'id': 2767364158, 'id_str': '2767364158', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Abuja, Nigeria
# country\r                                                 nigeria\r
# day                                                      2020-06-01
# hour                                                             08
# Name: 1399, dtype: object
# 1500
# created_at                                      2020-06-01 13-54-41
# id_str                                          1267454525331443715
# text              rt akscombat 5 crore pulwama 1 cr kerala flood...
# user              {'id': 4243762032, 'id_str': '4243762032', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Lucknow,India
# country\r                                                   india\r
# day                                                      2020-06-01
# hour                                                             13
# Name: 1499, dtype: object
# 1600
# created_at                                      2020-06-02 04-20-33
# id_str                                          1267672427817046019
# text              rt nccomfort hastingscenters erik parens sciam...
# user              {'id': 29684440, 'id_str': '29684440', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            London, England
# country\r                                          united kingdom\r
# day                                                      2020-06-02
# hour                                                             04
# Name: 1599, dtype: object
# 1700
# created_at                                      2020-06-01 16-02-01
# id_str                                          1267486569793048578
# text              rt spainmmg coronavirus spain 1 june latest he...
# user              {'id': 990113653415440384, 'id_str': '99011365...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Spain
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             16
# Name: 1699, dtype: object
# 1800
# created_at                                      2020-06-01 15-06-26
# id_str                                          1267472581810098179
# text              coronaisnotajoke covid19 pm imran khan solgan ...
# user              {'id': 1249253632920428544, 'id_str': '1249253...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Pakistan
# country\r                                                 پاکستان\r
# day                                                      2020-06-01
# hour                                                             15
# Name: 1799, dtype: object
# 1900
# created_at                                      2020-06-01 07-00-55
# id_str                                          1267350397552930816
# text              urgent motivation 105000 americans dead covid ...
# user              {'id': 40863984, 'id_str': '40863984', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Chocolate Town, USA
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             07
# Name: 1899, dtype: object
# 2000
# created_at                                      2020-06-01 20-34-37
# id_str                                          1267555171845971969
# text              rt 33trigger oil went negative covid didnt wee...
# user              {'id': 31632709, 'id_str': '31632709', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Western Kentucky
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             20
# Name: 1999, dtype: object
# 2100
# created_at                                      2020-06-01 22-33-21
# id_str                                          1267585052076097536
# text              rt ingarywetrustt truly cant believe fighting ...
# user              {'id': 320535738, 'id_str': '320535738', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                               Somewhere, looking good🤷🏽‍♀️
# country\r                                                       -\r
# day                                                      2020-06-01
# hour                                                             22
# Name: 2099, dtype: object
# 2200
# created_at                                      2020-06-01 11-35-30
# id_str                                          1267419498715504641
# text              rt karnapartahai called 1166 covid19helpline g...
# user              {'id': 832978643542491136, 'id_str': '83297864...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Mardan, Pakistan
# country\r                                                 پاکستان\r
# day                                                      2020-06-01
# hour                                                             11
# Name: 2199, dtype: object
# 2300
# created_at                                      2020-06-02 02-55-47
# id_str                                          1267651095578456066
# text              rt lissomelight oh god people really went maki...
# user              {'id': 337523307, 'id_str': '337523307', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Charlotte, NC
# country\r                                           united states\r
# day                                                      2020-06-02
# hour                                                             02
# Name: 2299, dtype: object
# 2400
# created_at                                      2020-06-02 03-42-39
# id_str                                          1267662889944518656
# text                                    lsaczak brexithome pandemic
# user              {'id': 922212687391678464, 'id_str': '92221268...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Planet Earth
# country\r                                               ประเทศไทย\r
# day                                                      2020-06-02
# hour                                                             03
# Name: 2399, dtype: object
# 2500
# created_at                                      2020-06-01 16-46-19
# id_str                                          1267497718274052104
# text              latino homes report serious covid19 symptoms n...
# user              {'id': 13604262, 'id_str': '13604262', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                      Springfield, Illinois
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             16
# Name: 2499, dtype: object
# 2600
# created_at                                      2020-06-01 11-11-05
# id_str                                          1267413354034810884
# text              rt spectatorindex us coronavirus deaths pass 1...
# user              {'id': 1238486083, 'id_str': '1238486083', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                Republic of the Philippines
# country\r                                             philippines\r
# day                                                      2020-06-01
# hour                                                             11
# Name: 2599, dtype: object
# 2700
# created_at                                      2020-06-01 07-01-33
# id_str                                          1267350556902817797
# text              rt uslawreview social distancing hand washing ...
# user              {'id': 1018800452517822464, 'id_str': '1018800...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              United States
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             07
# Name: 2699, dtype: object
# 2800
# created_at                                      2020-06-01 12-25-28
# id_str                                          1267432073234702336
# text              rt effsouthafrica cic julius_s_malema highligh...
# user              {'id': 264649788, 'id_str': '264649788', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Cape Town, South Africa
# country\r                                            south africa\r
# day                                                      2020-06-01
# hour                                                             12
# Name: 2799, dtype: object
# 2900
# created_at                                      2020-06-02 01-13-01
# id_str                                          1267625233487466498
# text              rt frankeljeremy finally gov whitmer lifts mic...
# user              {'id': 905218979148570625, 'id_str': '90521897...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   Florida
# country\r                                           united states\r
# day                                                      2020-06-02
# hour                                                             01
# Name: 2899, dtype: object
# 3000
# created_at                                      2020-06-01 17-34-47
# id_str                                          1267509915310047232
# text              rt likeasummerbres yall understand kept saying...
# user              {'id': 1228231641119645697, 'id_str': '1228231...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                        HTX
# country\r                                                 danmark\r
# day                                                      2020-06-01
# hour                                                             17
# Name: 2999, dtype: object
# 3100
# created_at                                      2020-06-02 01-59-52
# id_str                                          1267637023684415488
# text              rt matthewacherry took months figure testing c...
# user              {'id': 480958904, 'id_str': '480958904', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Minneapolis, MN
# country\r                                           united states\r
# day                                                      2020-06-02
# hour                                                             01
# Name: 3099, dtype: object
# 3200
# created_at                                      2020-06-01 13-19-03
# id_str                                          1267445557896888320
# text              rt ksau_hs pediatric emergency triage covid19 ...
# user              {'id': 2212189458, 'id_str': '2212189458', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    الأحساء
# country\r                                                السعودية\r
# day                                                      2020-06-01
# hour                                                             13
# Name: 3199, dtype: object
# 3300
# created_at                                      2020-06-01 15-42-24
# id_str                                          1267481633118130177
# text              rt cinjimmm curfew strictly enforced national ...
# user              {'id': 878528422938640384, 'id_str': '87852842...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    swt june 19th & dec 9th
# country\r                                                       -\r
# day                                                      2020-06-01
# hour                                                             15
# Name: 3299, dtype: object
# 3400
# created_at                                      2020-06-02 02-17-28
# id_str                                          1267641452877807620
# text              rt matthewacherry took months figure testing c...
# user              {'id': 852376419770519553, 'id_str': '85237641...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          harry styles’ ass
# country\r                                                       -\r
# day                                                      2020-06-02
# hour                                                             02
# Name: 3399, dtype: object
# 3500
# created_at                                      2020-06-01 18-35-25
# id_str                                          1267525174192209920
# text                        rt w_terrence coronavirus arrested riot
# user              {'id': 1007669011495178240, 'id_str': '1007669...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Sarasota, FL
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             18
# Name: 3499, dtype: object
# 3600
# created_at                                      2020-06-01 09-04-09
# id_str                                          1267381410236526592
# text              rt mitchellvii 89 new covid19 deaths recorded ...
# user              {'id': 531601992, 'id_str': '531601992', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                        USA
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             09
# Name: 3599, dtype: object
# 3700
# created_at                                      2020-06-02 02-41-42
# id_str                                          1267647551404204032
# text              rt nimalo_nisanto cant give food housing neces...
# user              {'id': 32768160, 'id_str': '32768160', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                   Germantown Philadelphia
# country\r                                           united states\r
# day                                                      2020-06-02
# hour                                                             02
# Name: 3699, dtype: object
# 3800
# created_at                                      2020-06-01 17-02-02
# id_str                                          1267501673485746177
# text                rt jahqnasty racism still biggest pandemic face
# user              {'id': 2508691364, 'id_str': '2508691364', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Santana
# country\r                                                  brasil\r
# day                                                      2020-06-01
# hour                                                             17
# Name: 3799, dtype: object
# 3900
# created_at                                      2020-06-01 08-05-02
# id_str                                          1267366533040390144
# text              rt maxalex66 tim matthews person lied spotting...
# user              {'id': 1164508470487523329, 'id_str': '1164508...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Hampshire UK
# country\r                                          united kingdom\r
# day                                                      2020-06-01
# hour                                                             08
# Name: 3899, dtype: object
# 4000
# created_at                                      2020-06-02 03-53-28
# id_str                                          1267665612077064194
# text              rt unswcentreideas 24 weeks time see spike cov...
# user              {'id': 902276340, 'id_str': '902276340', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Portland, Oregon
# country\r                                           united states\r
# day                                                      2020-06-02
# hour                                                             03
# Name: 3999, dtype: object
# 4100
# created_at                                      2020-06-01 23-54-48
# id_str                                          1267605549639585792
# text              rt necrosofty us cant organize testing centers...
# user              {'id': 1198755087310561281, 'id_str': '1198755...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Chicago Born/LA Living
# country\r                                                       -\r
# day                                                      2020-06-01
# hour                                                             23
# Name: 4099, dtype: object
# 4200
# created_at                                      2020-06-01 18-38-22
# id_str                                          1267525916592398342
# text              rt b__hen coronavirus listening dreams nightma...
# user              {'id': 1176302599991173120, 'id_str': '1176302...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  By myself
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             18
# Name: 4199, dtype: object
# 4300
# created_at                                      2020-06-01 16-32-21
# id_str                                          1267494203459801093
# text              rt helpfulkraken cant give money survive pande...
# user              {'id': 1151588557414420481, 'id_str': '1151588...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         enjoying happiness
# country\r                                                       -\r
# day                                                      2020-06-01
# hour                                                             16
# Name: 4299, dtype: object
# 4400
# created_at                                      2020-06-01 16-28-14
# id_str                                          1267493167466594304
# text              rt ssg_pain attempting establish new narrative...
# user              {'id': 1225949532216672256, 'id_str': '1225949...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              United States
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             16
# Name: 4399, dtype: object
# 4500
# created_at                                      2020-06-02 01-35-31
# id_str                                          1267630895802077186
# text              nygovcuomo city dies covid getting looted robb...
# user              {'id': 759785089408663552, 'id_str': '75978508...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Hollywood, FL
# country\r                                           united states\r
# day                                                      2020-06-02
# hour                                                             01
# Name: 4499, dtype: object
# 4600
# created_at                                      2020-06-01 11-26-11
# id_str                                          1267417154099523586
# text              rt hermanmashaba government 9 weeks prepare ea...
# user              {'id': 2530846347, 'id_str': '2530846347', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               South Africa
# country\r                                            south africa\r
# day                                                      2020-06-01
# hour                                                             11
# Name: 4599, dtype: object
# 4700
# created_at                                      2020-06-01 17-17-18
# id_str                                          1267505515464015872
# text              rt melanin_monroe1 im anti looting six months ...
# user              {'id': 841185020144308224, 'id_str': '84118502...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    she/her
# country\r                                                  polska\r
# day                                                      2020-06-01
# hour                                                             17
# Name: 4699, dtype: object
# 4800
# created_at                                      2020-06-01 14-53-16
# id_str                                          1267469268293124098
# text              dfds_uk look found clear lockdown northseasail...
# user              {'id': 951123640673865728, 'id_str': '95112364...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                   Scotland, United Kingdom
# country\r                                          united kingdom\r
# day                                                      2020-06-01
# hour                                                             14
# Name: 4799, dtype: object
# 4900
# created_at                                      2020-06-01 20-55-05
# id_str                                          1267560322472251394
# text              menners make ebola bed u dey try wake corona k...
# user              {'id': 844610915186196482, 'id_str': '84461091...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Sekondi Takoradi, Ghana
# country\r                                                   ghana\r
# day                                                      2020-06-01
# hour                                                             20
# Name: 4899, dtype: object
# 5000
# created_at                                      2020-06-01 23-17-01
# id_str                                          1267596041156792320
# text                 rt davidcorndc damn photo op social distancing
# user              {'id': 1165372153920917505, 'id_str': '1165372...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              County Durham
# country\r                                          united kingdom\r
# day                                                      2020-06-01
# hour                                                             23
# Name: 4999, dtype: object
# 5100
# created_at                                      2020-06-01 14-42-24
# id_str                                          1267466533611229191
# text              rt rhonddabryant westminster cant worst adapti...
# user              {'id': 949692936614285312, 'id_str': '94969293...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    England, United Kingdom
# country\r                                          united kingdom\r
# day                                                      2020-06-01
# hour                                                             14
# Name: 5099, dtype: object
# 5200
# created_at                                      2020-06-01 22-32-35
# id_str                                          1267584859146293249
# text              rt iamujer_ la suspending covid19 testing one ...
# user              {'id': 1241625891123236865, 'id_str': '1241625...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Oahu, Hawaii
# country\r                                           united states\r
# day                                                      2020-06-01
# hour                                                             22
# Name: 5199, dtype: object
# 5300
# created_at                                      2020-06-01 10-36-12
# id_str                                          1267404575360913410
# text              rt liverpoolcvs issues lockdown raised shielde...
# user              {'id': 2981123139, 'id_str': '2981123139', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Liverpool
# country\r                                          united kingdom\r
# day                                                      2020-06-01
# hour                                                             10
# Name: 5299, dtype: object
# 5400
# created_at                                      2020-06-01 09-40-32
# id_str                                          1267390566402318336
# text              rt brexitbin wow truly damning article british...
# user              {'id': 84580374, 'id_str': '84580374', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                A place in the rain. Europe
# country\r                                                       -\r
# day                                                      2020-06-01
# hour                                                             09
# Name: 5399, dtype: object
# 5500
# created_at                                      2020-06-01 21-25-48
# id_str                                          1267568052574576640
# text              rt maryxmaggot living pandemic historical revo...
# user              {'id': 967934908348936194, 'id_str': '96793490...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           jhs ksj jjk • 21
# country\r                                                       -\r
# day                                                      2020-06-01
# hour                                                             21
# Name: 5499, dtype: object
# 5600
# created_at                                      2020-06-01 17-04-41
# id_str                                          1267502340388655105
# text              rt abdul_majid84 breaking presidential task fo...
# user              {'id': 310477747, 'id_str': '310477747', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Bauchi, Nigeria
# country\r                                                 nigeria\r
# day                                                      2020-06-01
# hour                                                             17
# Name: 5599, dtype: object
# 5700
# created_at                                      2020-06-01 14-35-51
# id_str                                          1267464885253877761
# text                   chrisgiles_ kinch60 factor 2015 flu pandemic
# user              {'id': 1211610472035733505, 'id_str': '1211610...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# ...
# user              {'id': 198179597, 'id_str': '198179597', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              New York, USA
# country\r                                           united states\r
# day                                                      2020-06-30
# hour                                                             21
# Name: 334499, dtype: object
# 334600
# created_at                                      2020-06-30 09-44-29
# id_str                                          1277900808554778624
# text                                  worst yet come warns pandemic
# user              {'id': 68741628, 'id_str': '68741628', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Brighton-England
# country\r                                          united kingdom\r
# day                                                      2020-06-30
# hour                                                             09
# Name: 334599, dtype: object
# 334700
# created_at                                      2020-06-30 17-14-07
# id_str                                          1278013962479710208
# text              oh hey heres song havent changed clothes since...
# user              {'id': 162614244, 'id_str': '162614244', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Toronto, Ontario
# country\r                                                  canada\r
# day                                                      2020-06-30
# hour                                                             17
# Name: 334699, dtype: object
# 334800
# created_at                                      2020-06-30 11-15-18
# id_str                                          1277923663304671233
# text              rt markhart84 performance bbcnews bbcpanorama ...
# user              {'id': 17910730, 'id_str': '17910730', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Birmingham, England
# country\r                                          united kingdom\r
# day                                                      2020-06-30
# hour                                                             11
# Name: 334799, dtype: object
# 334900
# created_at                                      2020-06-30 15-54-29
# id_str                                          1277993922082594816
# text                            rt tlotlangmokoena covid20 pro plus
# user              {'id': 1021767251798700032, 'id_str': '1021767...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               South Africa
# country\r                                            south africa\r
# day                                                      2020-06-30
# hour                                                             15
# Name: 334899, dtype: object
# 335000
# created_at                                      2020-06-30 09-51-55
# id_str                                          1277902679184990208
# text              rt trivium21c children throughout country curr...
# user              {'id': 1013133055727493121, 'id_str': '1013133...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        South East, England
# country\r                                          united kingdom\r
# day                                                      2020-06-30
# hour                                                             09
# Name: 334999, dtype: object
# 335100
# created_at                                      2020-06-30 19-49-09
# id_str                                          1278052977903718400
# text              rt timrunshismouth instead sending covid patie...
# user              {'id': 582944730, 'id_str': '582944730', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 lala, land
# country\r                                             deutschland\r
# day                                                      2020-06-30
# hour                                                             19
# Name: 335099, dtype: object
# 335200
# created_at                                      2020-07-01 02-48-56
# id_str                                          1278158619821965312
# text              rt florian_krammer ischgl austria probably pla...
# user              {'id': 2260104096, 'id_str': '2260104096', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Islamabad
# country\r                                                 پاکستان\r
# day                                                      2020-07-01
# hour                                                             02
# Name: 335199, dtype: object
# 335300
# created_at                                      2020-06-30 21-03-29
# id_str                                          1278071684503748609
# text              rt sadcici im starbucks barista dealt white pe...
# user              {'id': 1140185725914079232, 'id_str': '1140185...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    —  4.27.20💘. 18+. nsfr.
# country\r                                                       -\r
# day                                                      2020-06-30
# hour                                                             21
# Name: 335299, dtype: object
# 335400
# created_at                                      2020-06-30 12-56-52
# id_str                                          1277949223380664320
# text              rt lisamei62 first masksthen vaccinesthen rfid...
# user              {'id': 800652126, 'id_str': '800652126', 'name...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Arkansas, USA
# country\r                                           united states\r
# day                                                      2020-06-30
# hour                                                             12
# Name: 335399, dtype: object
# 335500
# created_at                                      2020-06-30 15-51-21
# id_str                                          1277993133574426625
# text              rt wojespn positive tests coronavirus within t...
# user              {'id': 4865897506, 'id_str': '4865897506', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       Mississauga, Ontario
# country\r                                                  canada\r
# day                                                      2020-06-30
# hour                                                             15
# Name: 335499, dtype: object
# 335600
# created_at                                      2020-07-01 02-36-28
# id_str                                          1278155482470010885
# text              rt lookitstaylorrr shaming people unemployment...
# user              {'id': 1051955533, 'id_str': '1051955533', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Indianapolis
# country\r                                           united states\r
# day                                                      2020-07-01
# hour                                                             02
# Name: 335599, dtype: object
# 335700
# created_at                                      2020-06-30 15-28-09
# id_str                                          1277987295082102787
# text              sirajahashmi covid19 hadith 19 pens lifted pag...
# user              {'id': 2432896759, 'id_str': '2432896759', 'na...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                        USA
# country\r                                           united states\r
# day                                                      2020-06-30
# hour                                                             15
# Name: 335699, dtype: object
# 335800
# created_at                                      2020-06-30 08-01-13
# id_str                                          1277874820643016705
# text              rt chrisilluminati much like pandemic vintage ...
# user              {'id': 1003789641873575936, 'id_str': '1003789...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                       Void
# country\r                                                      中国\r
# day                                                      2020-06-30
# hour                                                             08
# Name: 335799, dtype: object
# 335900
# created_at                                      2020-06-30 23-16-14
# id_str                                          1278105092110065664
# text              rt pushmatrix weeks virtual training im finall...
# user              {'id': 849659483559264257, 'id_str': '84965948...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Francisco Sá
# country\r                                                  brasil\r
# day                                                      2020-06-30
# hour                                                             23
# Name: 335899, dtype: object
# 336000
# created_at                                      2020-07-01 05-42-44
# id_str                                          1278202358015635457
# text              rt its_yzee recorded track rt like utatakho ma...
# user              {'id': 86035399, 'id_str': '86035399', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               South Africa
# country\r                                            south africa\r
# day                                                      2020-07-01
# hour                                                             05
# Name: 335999, dtype: object
# 336100
# created_at                                      2020-06-30 19-43-25
# id_str                                          1278051535038144514
# text              national news coronavirus businesses inside le...
# user              {'id': 82047294, 'id_str': '82047294', 'name':...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                 Aylesbury, Buckinghamshire
# country\r                                          united kingdom\r
# day                                                      2020-06-30
# hour                                                             19
# Name: 336099, dtype: object
# 336200
# created_at                                      2020-06-30 14-43-41
# id_str                                          1277976104683241480
# text                      rt nkrankie leicester facing lockdown blm
# user              {'id': 1201757262555045888, 'id_str': '1201757...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                London Cali
# country\r                                          united kingdom\r
# day                                                      2020-06-30
# hour                                                             14
# Name: 336199, dtype: object
# 336300
# created_at                                      2020-07-01 02-45-31
# id_str                                          1278157759989657604
# text              rt dineshdsouza lets count masks oneonejust on...
# user              {'id': 959261020547158016, 'id_str': '95926102...
# lang                                                             en
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Austin, TX
# country\r                                           united states\r
# day                                                      2020-07-01
# hour                                                             02
# Name: 336299, dtype: object

# %%
df_tweets = pd.concat([df_tweets, df_emotions], axis=1)

# %%
df_tweets.to_csv(r"D:\covid research\output\step 3 output\2020-06-EN.csv")
