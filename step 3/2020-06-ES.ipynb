# %%
import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


from nltk.corpus import stopwords

from tqdm import tqdm
import os
import nltk
import spacy
spacy.require_gpu()
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")

from bs4 import BeautifulSoup

from datetime import date
# Out:
# c:\Users\hydro\anaconda3\envs\cov\lib\site-packages\cupy\_environment.py:205: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(

# %%
data_path = r"D:\covid research\output\step 2 output\2020-06-es"
days=os.listdir(data_path)
# days =[ i for i in days if i.split('.')[0].split('-')[-1]=='es']
print(days)

data_list = []
for i in days:
    file_path  = i
    path = os.path.join(data_path, file_path)
    print(path)
    df_day = pd.read_csv(path,lineterminator='\n')
    data_list.append(df_day)
df = pd.concat(data_list)
# Out:
# ['step2-output-ES-2020-06-01.csv', 'step2-output-ES-2020-06-02.csv', 'step2-output-ES-2020-06-04.csv', 'step2-output-ES-2020-06-05.csv', 'step2-output-ES-2020-06-06.csv', 'step2-output-ES-2020-06-07.csv', 'step2-output-ES-2020-06-08.csv', 'step2-output-ES-2020-06-09.csv', 'step2-output-ES-2020-06-10.csv', 'step2-output-ES-2020-06-11.csv', 'step2-output-ES-2020-06-12.csv', 'step2-output-ES-2020-06-13.csv', 'step2-output-ES-2020-06-14.csv', 'step2-output-ES-2020-06-15.csv', 'step2-output-ES-2020-06-16.csv', 'step2-output-ES-2020-06-17.csv', 'step2-output-ES-2020-06-18.csv', 'step2-output-ES-2020-06-19.csv', 'step2-output-ES-2020-06-20.csv', 'step2-output-ES-2020-06-21.csv', 'step2-output-ES-2020-06-22.csv', 'step2-output-ES-2020-06-23.csv', 'step2-output-ES-2020-06-24.csv', 'step2-output-ES-2020-06-25.csv', 'step2-output-ES-2020-06-26.csv', 'step2-output-ES-2020-06-27.csv', 'step2-output-ES-2020-06-28.csv', 'step2-output-ES-2020-06-29.csv', 'step2-output-ES-2020-06-30.csv']
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-01.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-02.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-04.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-05.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-06.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-07.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-08.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-09.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-10.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-11.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-12.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-13.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-14.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-15.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-16.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-17.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-18.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-19.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-20.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-21.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-22.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-23.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-24.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-25.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-26.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-27.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-28.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-29.csv
# D:\covid research\output\step 2 output\2020-06-es\step2-output-ES-2020-06-30.csv

# %%
df_date = df.copy(deep=True)
df_date['day'] = df_date['created_at'].apply(lambda x: x.split(' ')[0])
df_date['hour'] = df_date['created_at'].apply(lambda x: x.split(' ')[1])
df_date['hour'] = df_date['hour'].apply(lambda x: x.split('-')[0])
#start_date = '2020-03-' + '%.2d' % start
#end_date = '2020-03-' + '%.2d' % (end + 1)

#selected_date = (df_date['day'] != start_date) & (df_date['day'] != end_date)
df_01 = df_date.copy(deep=True)
df_01 = df_01.reset_index(drop=True)
day_count = df_01.groupby('day').count()['text']

# %% [markdown]
# # Preprocessing

# %%
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
df_01['text'] = df_01['text'].apply(lambda x: remove_emoji(x))
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df_01['text'] = df_01['text'].apply(lambda x: BeautifulSoup(x, "html.parser").get_text())
df_01['text'] = df_01['text'].apply(lambda x: re.sub('\[[^]]*\]', '', x))
df_01['text'] = df_01['text'].apply(lambda x: re.sub(r'http\S+', '', x))
df_01['text'] = df_01['text'].str.replace('[^\w\s]','')
import nltk
nltk.download('stopwords')
stop = set(stopwords.words('spanish'))
punctuation = list(string.punctuation)
stop.update(punctuation)
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
def remove_xml(text):
    return re.sub(r'<[^<]+?>', '', text)

def remove_newlines(text):
    return text.replace('\n', ' ') 
    

def remove_manyspaces(text):
    return re.sub(r'\s+', ' ', text)

def clean_text(text):
    text = remove_xml(text)
    text = remove_newlines(text)
    text = remove_manyspaces(text)
    return text
df_01['text']= df_01['text'].apply(clean_text)
df_02 = df_01.copy()
nlp = spacy.load('es_core_news_sm')
# lemmatizatioin using Spacy to count the appearance of each word
def space (comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df_02['text']= df_02['text'].apply(space)
df_02['text'].head(20)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0     rt andyws0k coronavirus malén galmarini decir ...
# 1     rt soulsearcher_dr sanitario covid_19 improvis...
# 2     rt elcoya1977 buen día ginés garcía armar plen...
# 3     rt mazzolenijulio informe covid19 1 junio proc...
# 4     rt droscarnoguerar atención seguir aumento tas...
# 5     rt mifutbolecuador experto italiano asegurar c...
# 6     rt gabrielrufiar pandemia surgido chino pandem...
# 7     rt m4neugly coronavirus ver centro atención mundo
# 8     pedianu putin soltar león call obligar gente q...
# 9     covid19 venir próximo semana conversar exdirec...
# 10    rt carlitoselnicar conmovedor pintor jerezano ...
# 11    rt latercerar catterina ferreccio epidemiólogo...
# 12    rt gabrielrufiar pandemia surgido chino pandem...
# 13    rt lolangostinir dónde creéis ir instagram dig...
# 14    rt pabloagustin pelicula suspenso drama acción...
# 15    rt m4neugly coronavirus ver centro atención mundo
# 16    rt jesuscintoro fortunir 23 español rico crece...
# 17    rt iamv2020 fin mundo ebola coronavirus purga ...
# 18    rt isaacd7777 tal tierra nooo hermano pregunte...
# 19    alcanzar chihuahua 2033 caso covid19 sumar 331...
# Name: text, dtype: object

# %% [markdown]
# # NRC

# %%
ncr = pd.read_excel("D:/covid research/src/local_exe/step 3/NRC-Emotion-Lexicon-v0.92-In105Languages-Nov2017Translations.xlsx")
ncr = ncr[['English (en)', 'Spanish (es)', 'Positive', 'Negative', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']]
ncr = ncr[ncr['Spanish (es)'] != 'NO TRANSLATION'].reset_index(drop=True)
emotions = ['Anger', 'Anticipation','Disgust','Fear', 'Joy','Sadness', 'Surprise', 'Trust']
def join_edited_string(edited_tweets):
    
    edited_string = ''
    for row in edited_tweets:
        edited_string = edited_string + ' ' + row
        
    return edited_string

joined_string = join_edited_string(df_01['text'])

tokens = joined_string.split(' ')

joined_string1 = join_edited_string(df_02['text'])
tokens1 = joined_string1.split(' ')

unique_words = set(tokens)
unique_words1 = set(tokens1)
unique_words.update(unique_words1)
word_to_ind = dict((word, i) for i, word in enumerate(unique_words))
ind_to_word = dict((i, word) for i, word in enumerate(unique_words))

# %%
import nltk
nltk.download('punkt')
from collections import defaultdict
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_tweets = df_01.copy(deep=True)
df_tweets1 = df_02.copy(deep=True)
emo_info = {'emotion':'' , 'emo_frq': defaultdict(int) }
list_emotion_counts = []
for emotion in emotions:
        emo_info = {}
        emo_info['emotion'] = emotion
        emo_info['emo_frq'] = defaultdict(int)
        list_emotion_counts.append(emo_info)
nrow = df_tweets.shape[0]
df_emotions = pd.DataFrame(0, index=df_tweets.index, columns=emotions)

# %%
process_count=0
for i in range(nrow):
        process_count+=1
        if process_count %100==0:
            print(process_count)
            print(df_tweets.loc[i])
        tweet = word_tokenize(df_tweets.loc[i]['text'], language='spanish')
        for word in tweet:
            word_stemmed = word
            result = ncr[ncr['Spanish (es)'] == word_stemmed]
            if not result.empty:
                # update the tweet-emotions counts
                for idx, emotion in enumerate(emotions):
                    df_emotions.at[i, emotion] += result[emotion].iloc[0]
                    # update the frequencies dictionary list
                    if result[emotion].iloc[0].any():
                        try:
                            list_emotion_counts[idx]['emo_frq'][word_to_ind[word]] += 1
                        except:
                            continue
            else:
                doc = nlp(word)
                word_stemmed1 = " ".join([token.lemma_ for token in doc]).lower()
                result1 = ncr[ncr['Spanish (es)'] == word_stemmed1]
                if not result1.empty:
                    # update the tweet-emotions counts
                    for idx, emotion in enumerate(emotions):
                        df_emotions.at[i, emotion] += result1[emotion].iloc[0]
                        # update the frequencies dictionary list
                        if result1[emotion].iloc[0].any():
                            try:
                                list_emotion_counts[idx]['emo_frq'][word_to_ind[word_stemmed1]] += 1
                            except:
                                continue
# Out:
# 100
# created_at                                      2020-06-02 00-52-44
# id_str                                          1267620129019396098
# text              último indígenas colombia gracias manuelandrio...
# user              {'id': 114511956, 'id_str': '114511956', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   Colombia
# country\r                                                colombia\r
# day                                                      2020-06-02
# hour                                                             00
# Name: 99, dtype: object
# 200
# created_at                                      2020-06-01 06-44-00
# id_str                                          1267346140313288705
# text              rt secrenferum proyecto ningún estudiante atrá...
# user              {'id': 1356450685, 'id_str': '1356450685', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Murcia, España
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             06
# Name: 199, dtype: object
# 300
# created_at                                      2020-06-02 02-39-21
# id_str                                          1267646960015728644
# text              rt walterdossier pueblo rodríguezñáñez impiden...
# user              {'id': 2438644227, 'id_str': '2438644227', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                   Nueva Esparta, Venezuela
# country\r                                               venezuela\r
# day                                                      2020-06-02
# hour                                                             02
# Name: 299, dtype: object
# 400
# created_at                                      2020-06-01 09-51-52
# id_str                                          1267393418533261312
# text              rt dmarenco9 personas afuera casa blanca medio...
# user              {'id': 1202364993343234051, 'id_str': '1202364...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   Colombia
# country\r                                                colombia\r
# day                                                      2020-06-01
# hour                                                             09
# Name: 399, dtype: object
# 500
# created_at                                      2020-06-01 13-23-05
# id_str                                          1267446572931067905
# text                   rt verolozanovl creadores flequillo pandemia
# user              {'id': 2768731438, 'id_str': '2768731438', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Argentina
# country\r                                               argentina\r
# day                                                      2020-06-01
# hour                                                             13
# Name: 499, dtype: object
# 600
# created_at                                      2020-06-01 15-28-55
# id_str                                          1267478239922003968
# text              rt lolangostino dónde creéis van instagram dig...
# user              {'id': 2312148846, 'id_str': '2312148846', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Granada, España
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             15
# Name: 599, dtype: object
# 700
# created_at                                      2020-06-02 02-42-29
# id_str                                          1267647748523929602
# text              rt policiaecuador 1700 pruebas rápidas covid19...
# user              {'id': 1220355793494605824, 'id_str': '1220355...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-06-02
# hour                                                             02
# Name: 699, dtype: object
# 800
# created_at                                      2020-06-02 00-52-23
# id_str                                          1267620040964280321
# text              rt sweetsalvat0re corona virus viendo nadie habla
# user              {'id': 750325201162924032, 'id_str': '75032520...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Valencia, España
# country\r                                                  españa\r
# day                                                      2020-06-02
# hour                                                             00
# Name: 799, dtype: object
# 900
# created_at                                      2020-06-01 20-43-04
# id_str                                          1267557298345476099
# text              rt alferdez hoy pilar pusimos marcha hospital ...
# user              {'id': 1267247729278889986, 'id_str': '1267247...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Morón, Argentina
# country\r                                               argentina\r
# day                                                      2020-06-01
# hour                                                             20
# Name: 899, dtype: object
# 1000
# created_at                                      2020-06-01 16-36-00
# id_str                                          1267495121982910464
# text              rt kingbarrioes gente estupida creerá partir m...
# user              {'id': 396138920, 'id_str': '396138920', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                  Mexicali, Baja California
# country\r                                                  méxico\r
# day                                                      2020-06-01
# hour                                                             16
# Name: 999, dtype: object
# 1100
# created_at                                      2020-06-02 04-53-20
# id_str                                          1267680678004625409
# text              rt presidenciasv salvador sido países mejor co...
# user              {'id': 1240481265448554497, 'id_str': '1240481...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                El Salvador
# country\r                                             el salvador\r
# day                                                      2020-06-02
# hour                                                             04
# Name: 1099, dtype: object
# 1200
# created_at                                      2020-06-01 18-17-56
# id_str                                          1267520774379839495
# text              rt m4neugly coronavirus viendo centro atención...
# user              {'id': 1015273982101159936, 'id_str': '1015273...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     España
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             18
# Name: 1199, dtype: object
# 1300
# created_at                                      2020-06-01 15-41-18
# id_str                                          1267481356273168388
# text              rt _worldravers_ enero posible 3era guerra mun...
# user              {'id': 1035994390655889408, 'id_str': '1035994...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Chile
# country\r                                                   chile\r
# day                                                      2020-06-01
# hour                                                             15
# Name: 1299, dtype: object
# 1400
# created_at                                      2020-06-01 23-23-21
# id_str                                          1267597634975473670
# text              rt embespestocolmo si interesa actual debate d...
# user              {'id': 362343279, 'id_str': '362343279', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Stockholm, Sweden
# country\r                                                 sverige\r
# day                                                      2020-06-01
# hour                                                             23
# Name: 1399, dtype: object
# 1500
# created_at                                      2020-06-02 01-31-30
# id_str                                          1267629884999970818
# text              rt mirkinho_rules maneras seductoras demostrar...
# user              {'id': 1256030562176741376, 'id_str': '1256030...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Lima, Peru
# country\r                                                    perú\r
# day                                                      2020-06-02
# hour                                                             01
# Name: 1499, dtype: object
# 1600
# created_at                                      2020-06-02 03-18-25
# id_str                                          1267656791434780672
# text              rt infoinfusiondgo aumentaron hoy 17 casos cov...
# user              {'id': 51105804, 'id_str': '51105804', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Durango, Dgo. Méx.
# country\r                                                  méxico\r
# day                                                      2020-06-02
# hour                                                             03
# Name: 1599, dtype: object
# 1700
# created_at                                      2020-06-01 14-52-20
# id_str                                          1267469033445654529
# text              rt miriamcorona140 miryam1968 bien explicado m...
# user              {'id': 2751530009, 'id_str': '2751530009', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                France 🌞🇫🇷🌞
# country\r                                                  france\r
# day                                                      2020-06-01
# hour                                                             14
# Name: 1699, dtype: object
# 1800
# created_at                                      2020-06-01 08-27-07
# id_str                                          1267372090476449792
# text              rt populares bajada cifras 8m debido coronavir...
# user              {'id': 3405440758, 'id_str': '3405440758', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                             Las Palmas de Gran Canaria, Es
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             08
# Name: 1799, dtype: object
# 1900
# created_at                                      2020-06-02 03-37-21
# id_str                                          1267661556172668929
# text              coronavirus trabajador dio positivo test rápid...
# user              {'id': 1932607728, 'id_str': '1932607728', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                  Oliva, Córdoba, Argentina
# country\r                                               argentina\r
# day                                                      2020-06-02
# hour                                                             03
# Name: 1899, dtype: object
# 2000
# created_at                                      2020-06-01 18-49-13
# id_str                                          1267528647059156998
# text              rt m4neugly coronavirus viendo centro atención...
# user              {'id': 1054479724653830146, 'id_str': '1054479...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Málaga, España
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             18
# Name: 1999, dtype: object
# 2100
# created_at                                      2020-06-01 12-59-55
# id_str                                          1267440742848434178
# text              rt giubeeh bueno menos peor pandemia pasó segu...
# user              {'id': 215782272, 'id_str': '215782272', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Starkiller Base
# country\r                                                       -\r
# day                                                      2020-06-01
# hour                                                             12
# Name: 2099, dtype: object
# 2200
# created_at                                      2020-06-02 05-36-03
# id_str                                          1267691427988942848
# text              rt rolandoenserio solo coronavirus ahora colap...
# user              {'id': 146200495, 'id_str': '146200495', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       Maracaibo, Venezuela
# country\r                                               venezuela\r
# day                                                      2020-06-02
# hour                                                             05
# Name: 2199, dtype: object
# 2300
# created_at                                      2020-06-02 04-59-02
# id_str                                          1267682112460722176
# text              rt pablogcabiedes superdrasticas tía países eu...
# user              {'id': 844229742, 'id_str': '844229742', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     España
# country\r                                                  españa\r
# day                                                      2020-06-02
# hour                                                             04
# Name: 2299, dtype: object
# 2400
# created_at                                      2020-06-01 19-51-40
# id_str                                          1267544363107835909
# text              dzapatillas bcrausuarios hablando democracia p...
# user              {'id': 398490148, 'id_str': '398490148', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Argentina
# country\r                                               argentina\r
# day                                                      2020-06-01
# hour                                                             19
# Name: 2399, dtype: object
# 2500
# created_at                                      2020-06-01 12-56-55
# id_str                                          1267439987852787715
# text              ayuso desautoriza socio gobierno madrid negoci...
# user              {'id': 282292651, 'id_str': '282292651', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                 L'Hospitalet/Blanes/Madrid
# country\r                                                       -\r
# day                                                      2020-06-01
# hour                                                             12
# Name: 2499, dtype: object
# 2600
# created_at                                      2020-06-02 00-44-41
# id_str                                          1267618103187431425
# text              rt okdobleamarilla alerta agustín cardozo juga...
# user              {'id': 1003158142195322881, 'id_str': '1003158...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Rosario, Argentina
# country\r                                               argentina\r
# day                                                      2020-06-02
# hour                                                             00
# Name: 2599, dtype: object
# 2700
# created_at                                      2020-06-01 14-29-29
# id_str                                          1267463283050774528
# text              rt smravenna coronavirusargentina ahora laplat...
# user              {'id': 4788270881, 'id_str': '4788270881', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        La Plata, Argentina
# country\r                                               argentina\r
# day                                                      2020-06-01
# hour                                                             14
# Name: 2699, dtype: object
# 2800
# created_at                                      2020-06-01 13-36-38
# id_str                                          1267449982896005121
# text              datos covid19 madrid inicio 01062020 60 casos ...
# user              {'id': 134414411, 'id_str': '134414411', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Madrid
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             13
# Name: 2799, dtype: object
# 2900
# created_at                                      2020-06-02 05-59-07
# id_str                                          1267697232918253568
# text              bearicoactriz bea alegro menos muertos covid s...
# user              {'id': 303802417, 'id_str': '303802417', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     España
# country\r                                                  españa\r
# day                                                      2020-06-02
# hour                                                             05
# Name: 2899, dtype: object
# 3000
# created_at                                      2020-06-01 14-39-26
# id_str                                          1267465787025088512
# text              rt dect1608 unas horas superar 10mil muertes c...
# user              {'id': 189399036, 'id_str': '189399036', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Tampico, Tamaulipas
# country\r                                                  méxico\r
# day                                                      2020-06-01
# hour                                                             14
# Name: 2999, dtype: object
# 3100
# created_at                                      2020-06-01 20-52-01
# id_str                                          1267559550699347970
# text              rt jaemin_king donald trump escondido bunker c...
# user              {'id': 2756932656, 'id_str': '2756932656', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Cádiz, España
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             20
# Name: 3099, dtype: object
# 3200
# created_at                                      2020-06-01 14-43-02
# id_str                                          1267466693019869185
# text              rt lolangostino dónde creéis van instagram dig...
# user              {'id': 1166275630964596736, 'id_str': '1166275...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Elda, España
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             14
# Name: 3199, dtype: object
# 3300
# created_at                                      2020-06-01 22-31-01
# id_str                                          1267584464873328640
# text              últimominuto reporta ssalud_tab 181 casos covi...
# user              {'id': 150913226, 'id_str': '150913226', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                              Villahermosa, Tabasco, México
# country\r                                                  méxico\r
# day                                                      2020-06-01
# hour                                                             22
# Name: 3299, dtype: object
# 3400
# created_at                                      2020-06-01 17-18-53
# id_str                                          1267505913948233729
# text              rt gonzalo2020rd apoyo continúa empresas proye...
# user              {'id': 1112247290, 'id_str': '1112247290', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Dominican Republic
# country\r                                    república dominicana\r
# day                                                      2020-06-01
# hour                                                             17
# Name: 3399, dtype: object
# 3500
# created_at                                      2020-06-01 11-11-13
# id_str                                          1267413387601993730
# text              rt gabrielrufian pandemia surgida china pandem...
# user              {'id': 183339683, 'id_str': '183339683', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Madrid
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             11
# Name: 3499, dtype: object
# 3600
# created_at                                      2020-06-01 07-58-59
# id_str                                          1267365010491269122
# text              rt bravelwtsolo anonymous denunciando presenta...
# user              {'id': 812633803411832832, 'id_str': '81263380...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                       4AND
# country\r                                                   नेपाल\r
# day                                                      2020-06-01
# hour                                                             07
# Name: 3599, dtype: object
# 3700
# created_at                                      2020-06-01 10-40-15
# id_str                                          1267405594572599302
# text              rt daniel_sanz_c sanchezcastejon españa 3 4 in...
# user              {'id': 759799806122336258, 'id_str': '75979980...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                  Reino de España 🇪🇸 Aragón
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             10
# Name: 3699, dtype: object
# 3800
# created_at                                      2020-06-01 12-03-12
# id_str                                          1267426469619384320
# text              rt fijatetu_erestu coronavirus detiene talento...
# user              {'id': 2333615957, 'id_str': '2333615957', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                     Medina-Sidonia, España
# country\r                                                  españa\r
# day                                                      2020-06-01
# hour                                                             12
# Name: 3799, dtype: object
# 3900
# created_at                                      2020-06-01 07-07-21
# id_str                                          1267352016524894208
# text              omarfayadcomunica spyescrececontigo hidalgo re...
# user              {'id': 1048053014412644352, 'id_str': '1048053...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                   Pachuca de Soto, Hidalgo
# country\r                                                  méxico\r
# day                                                      2020-06-01
# hour                                                             07
# Name: 3899, dtype: object
# 4000
# created_at                                      2020-06-01 18-39-59
# id_str                                          1267526323439833089
# text              rt laradioredonda alfaro moreno presidente bar...
# user              {'id': 1202273220, 'id_str': '1202273220', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Guayaquil
# country\r                                                 ecuador\r
# day                                                      2020-06-01
# hour                                                             18
# Name: 3999, dtype: object
# 4100
# created_at                                      2020-06-02 17-44-00
# id_str                                          1267874622629908487
# text              rt froillannister dice gobierno fallecido coro...
# user              {'id': 914416547132829696, 'id_str': '91441654...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     España
# country\r                                                  españa\r
# day                                                      2020-06-02
# hour                                                             17
# Name: 4099, dtype: object
# 4200
# created_at                                      2020-06-03 01-56-15
# id_str                                          1267998501381734400
# text              rt vtvcanal8 ops advierte reapertura precoz me...
# user              {'id': 1230568240721559553, 'id_str': '1230568...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Caracas, Venezuela
# country\r                                               venezuela\r
# day                                                      2020-06-03
# hour                                                             01
# Name: 4199, dtype: object
# 4300
# created_at                                      2020-06-02 22-42-18
# id_str                                          1267949692257816576
# text              rt lolicastaldo semana atrás festejaban covid ...
# user              {'id': 2149387671, 'id_str': '2149387671', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              La Plata city
# country\r                                           united states\r
# day                                                      2020-06-02
# hour                                                             22
# Name: 4299, dtype: object
# 4400
# created_at                                      2020-06-02 20-31-13
# id_str                                          1267916704069423104
# text              rt astroshipps marcha calle celebran seguimos ...
# user              {'id': 2550232040, 'id_str': '2550232040', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Mi cama
# country\r                                                  brasil\r
# day                                                      2020-06-02
# hour                                                             20
# Name: 4399, dtype: object
# 4500
# created_at                                      2020-06-02 08-35-29
# id_str                                          1267736583870058497
# text              covid19 dejado imágenes inusuales miles animal...
# user              {'id': 915317562287824897, 'id_str': '91531756...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Al-Ándalus
# country\r                                                السعودية\r
# day                                                      2020-06-02
# hour                                                             08
# Name: 4499, dtype: object
# 4600
# created_at                                      2020-06-02 16-43-56
# id_str                                          1267859506362548224
# text              rt daviiidcarrillo imagínate ser presidente im...
# user              {'id': 976915582581960705, 'id_str': '97691558...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            22/7 le abracé
# country\r                                                       -\r
# day                                                      2020-06-02
# hour                                                             16
# Name: 4599, dtype: object
# 4700
# created_at                                      2020-06-02 16-10-30
# id_str                                          1267851092580347904
# text              rt pmercado2006 covid__19 puesto evidencia fal...
# user              {'id': 1321152943, 'id_str': '1321152943', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Bogotá D.C.
# country\r                                                colombia\r
# day                                                      2020-06-02
# hour                                                             16
# Name: 4699, dtype: object
# 4800
# created_at                                      2020-06-02 17-30-10
# id_str                                          1267871141349203971
# text              rt minsapcuba confirmaron 9 nuevos casos covid...
# user              {'id': 877156619251056641, 'id_str': '87715661...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Panamá
# country\r                                                  panamá\r
# day                                                      2020-06-02
# hour                                                             17
# Name: 4799, dtype: object
# 4900
# created_at                                      2020-06-03 03-31-33
# id_str                                          1268022484433076224
# text              rt reporte_indigo perú covid19 da tregua númer...
# user              {'id': 604744987, 'id_str': '604744987', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     México
# country\r                                                  méxico\r
# day                                                      2020-06-03
# hour                                                             03
# Name: 4899, dtype: object
# 5000
# created_at                                      2020-06-02 17-33-34
# id_str                                          1267871996982984706
# text              rt majomontilla ponga fotos instagram ponga fo...
# user              {'id': 196457143, 'id_str': '196457143', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Buenos Aires, Argentina
# country\r                                               argentina\r
# day                                                      2020-06-02
# hour                                                             17
# Name: 4999, dtype: object
# 5100
# created_at                                      2020-06-02 16-44-02
# id_str                                          1267859531511595008
# text              angelsolismx1 presenta relevante querétaro méx...
# user              {'id': 328762425, 'id_str': '328762425', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Querétaro, México
# country\r                                                  méxico\r
# day                                                      2020-06-02
# hour                                                             16
# Name: 5099, dtype: object
# 5200
# created_at                                      2020-06-02 17-26-21
# id_str                                          1267870180845256711
# text              rt donegramatea 2jun venezuela inicia nueva fa...
# user              {'id': 1426467668, 'id_str': '1426467668', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                  Venezuela.  0416-7161087
# country\r                                                       -\r
# day                                                      2020-06-02
# hour                                                             17
# Name: 5199, dtype: object
# 5300
# created_at                                      2020-06-02 11-59-25
# id_str                                          1267787905398976512
# text              rt proceso últimahora primer día nueva normali...
# user              {'id': 36493345, 'id_str': '36493345', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            "El no tiempo"
# country\r                                               argentina\r
# day                                                      2020-06-02
# hour                                                             11
# Name: 5299, dtype: object
# 5400
# created_at                                      2020-06-02 19-56-10
# id_str                                          1267907883443933184
# text              buenas tardes país importante ir inaugurar tre...
# user              {'id': 718867043030700032, 'id_str': '71886704...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Hermosillo, Sonora
# country\r                                                  méxico\r
# day                                                      2020-06-02
# hour                                                             19
# Name: 5399, dtype: object
# 5500
# created_at                                      2020-06-02 19-35-39
# id_str                                          1267902720272470018
# text              rt cakonicaragua irónicamente covid19 anda pla...
# user              {'id': 927734660070813696, 'id_str': '92773466...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Nicaragua
# country\r                                               nicaragua\r
# day                                                      2020-06-02
# hour                                                             19
# Name: 5499, dtype: object
# 5600
# created_at                                      2020-06-02 13-45-10
# id_str                                          1267814518240903171
# text              rt soymiguellago pandemia pablo olvidado pandemia
# user              {'id': 61231740, 'id_str': '61231740', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Chande
# country\r                                                   india\r
# day                                                      2020-06-02
# hour                                                             13
# Name: 5599, dtype: object
# 5700
# created_at                                      2020-06-02 21-53-01
# id_str                                          1267937289713352706
# text              rt fabricelelous muriendo altos cargos sandini...
# user              {'id': 232940543, 'id_str': '232940543', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# ...
# text              rt porttada lasnoticiasmásleídas presidente na...
# user              {'id': 1250605797471653891, 'id_str': '1250605...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Estados Unidos
# country\r                                           united states\r
# day                                                      2020-06-30
# hour                                                             19
# Name: 87099, dtype: object
# 87200
# created_at                                      2020-07-01 01-41-16
# id_str                                          1278141590968717312
# text              rt gbastidas exgobernador hcapriles considera ...
# user              {'id': 631480646, 'id_str': '631480646', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Carabobo, Venezuela
# country\r                                               venezuela\r
# day                                                      2020-07-01
# hour                                                             01
# Name: 87199, dtype: object
# 87300
# created_at                                      2020-07-01 00-47-23
# id_str                                          1278128030767099904
# text              rt doctormacias ojalá pandemia covid haga deje...
# user              {'id': 578383981, 'id_str': '578383981', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                             Mexico,D.F. _Estado de México
# country\r                                                  méxico\r
# day                                                      2020-07-01
# hour                                                             00
# Name: 87299, dtype: object
# 87400
# created_at                                      2020-07-01 04-34-38
# id_str                                          1278185220085288963
# text              rt ijulianaguilera pandemia demostró gente pue...
# user              {'id': 241721774, 'id_str': '241721774', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Bogotá - Colombia
# country\r                                                colombia\r
# day                                                      2020-07-01
# hour                                                             04
# Name: 87399, dtype: object
# 87500
# created_at                                      2020-07-01 01-50-30
# id_str                                          1278143914579505153
# text              rt ddavidvillamar hoy preocupa pandemia quiere...
# user              {'id': 1060316049256669184, 'id_str': '1060316...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Quito, Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-07-01
# hour                                                             01
# Name: 87499, dtype: object
# 87600
# created_at                                      2020-06-30 13-52-07
# id_str                                          1277963127506624512
# text              estudio europeo coloca españa país ue muertos ...
# user              {'id': 589454860, 'id_str': '589454860', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Madrid
# country\r                                                  españa\r
# day                                                      2020-06-30
# hour                                                             13
# Name: 87599, dtype: object
# 87700
# created_at                                      2020-07-01 01-35-52
# id_str                                          1278140231976472578
# text              rt teamocoro_14 modoactivo independenciaypaz u...
# user              {'id': 949833490543136768, 'id_str': '94983349...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         BIRUACA EDO. APURE
# country\r                                                       -\r
# day                                                      2020-07-01
# hour                                                             01
# Name: 87699, dtype: object
# 87800
# created_at                                      2020-06-30 11-34-59
# id_str                                          1277928616760946690
# text              rt nonaossandon recién hermano mjossandon reci...
# user              {'id': 367982886, 'id_str': '367982886', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Aysen
# country\r                                                   chile\r
# day                                                      2020-06-30
# hour                                                             11
# Name: 87799, dtype: object
# 87900
# created_at                                      2020-06-30 11-03-01
# id_str                                          1277920572119400448
# text              rt expansioncom oms avisa pandemia lejos haber...
# user              {'id': 3172138743, 'id_str': '3172138743', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Madrid
# country\r                                                  españa\r
# day                                                      2020-06-30
# hour                                                             11
# Name: 87899, dtype: object
# 88000
# created_at                                      2020-06-30 14-35-12
# id_str                                          1277973969803464705
# text              rt sgilsantiago covid rápido furioso caricatur...
# user              {'id': 391681824, 'id_str': '391681824', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Panamá
# country\r                                                  panamá\r
# day                                                      2020-06-30
# hour                                                             14
# Name: 87999, dtype: object
# 88100
# created_at                                      2020-06-30 20-12-44
# id_str                                          1278058912839655424
# text              rt frankievillamx carlos romero deschamps mord...
# user              {'id': 589643155, 'id_str': '589643155', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Guanajuato
# country\r                                                  méxico\r
# day                                                      2020-06-30
# hour                                                             20
# Name: 88099, dtype: object
# 88200
# created_at                                      2020-06-30 22-01-30
# id_str                                          1278086284846784515
# text              rt espaciofutboi buenas noticias freddy lopez ...
# user              {'id': 571180912, 'id_str': '571180912', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                   GUATEMALA CENTRO AMERICA
# country\r                                               argentina\r
# day                                                      2020-06-30
# hour                                                             22
# Name: 88199, dtype: object
# 88300
# created_at                                      2020-06-30 22-25-53
# id_str                                          1278092421113536512
# text              david_rguez7 jesus_br_ sabe viene pandemia va ...
# user              {'id': 962037392, 'id_str': '962037392', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Eivissa, España
# country\r                                                  españa\r
# day                                                      2020-06-30
# hour                                                             22
# Name: 88299, dtype: object
# 88400
# created_at                                      2020-07-01 01-28-14
# id_str                                          1278138310997602305
# text              rt ecuadorenvivo covid19 solórzano reconoce ec...
# user              {'id': 1269749608135233538, 'id_str': '1269749...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-07-01
# hour                                                             01
# Name: 88399, dtype: object
# 88500
# created_at                                      2020-06-30 16-42-27
# id_str                                          1278005993285222403
# text              rt alvarouribevel joya corona tomarse colombia...
# user              {'id': 157424673, 'id_str': '157424673', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                🇺🇸 🇻🇪 🇨🇴 🇦🇷
# country\r                                                       -\r
# day                                                      2020-06-30
# hour                                                             16
# Name: 88499, dtype: object
# 88600
# created_at                                      2020-07-01 00-26-38
# id_str                                          1278122808850202626
# text              rt doctoramuchacha cruda realidad aún crees co...
# user              {'id': 2369573840, 'id_str': '2369573840', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                               Atizapán de Zaragoza, México
# country\r                                                  méxico\r
# day                                                      2020-07-01
# hour                                                             00
# Name: 88599, dtype: object
# 88700
# created_at                                      2020-06-30 13-16-02
# id_str                                          1277954046859661312
# text              rt juanizio_c partir datos defunciones covid_1...
# user              {'id': 991545193, 'id_str': '991545193', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Concepción, Chile
# country\r                                                   chile\r
# day                                                      2020-06-30
# hour                                                             13
# Name: 88699, dtype: object
# 88800
# created_at                                      2020-07-01 00-59-52
# id_str                                          1278131172300783616
# text              avance mensual contagios covid19 totales casos...
# user              {'id': 1405621242, 'id_str': '1405621242', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Montevideo, Uruguay
# country\r                                                 uruguay\r
# day                                                      2020-07-01
# hour                                                             00
# Name: 88799, dtype: object
# 88900
# created_at                                      2020-06-30 16-39-07
# id_str                                          1278005154441244672
# text              rt madorni actividad económica abril cayó 264 ...
# user              {'id': 177012027, 'id_str': '177012027', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Argentina
# country\r                                               argentina\r
# day                                                      2020-06-30
# hour                                                             16
# Name: 88899, dtype: object

# %%
df_tweets = pd.concat([df_tweets, df_emotions], axis=1)

# %%
df_tweets.to_csv(r"D:\covid research\output\step 3 output\2020-06-ES.csv")
