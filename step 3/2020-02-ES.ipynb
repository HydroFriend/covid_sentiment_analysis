# %%
import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


from nltk.corpus import stopwords

from tqdm import tqdm
import os
import nltk
import spacy
spacy.require_gpu()
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")

from bs4 import BeautifulSoup

from datetime import date

# %%
data_path = r"D:\covid research\output\step 2 output\2020-02-es"
days=os.listdir(data_path)
# days =[ i for i in days if i.split('.')[0].split('-')[-1]=='es']
print(days)

data_list = []
for i in days:
    file_path  = i
    path = os.path.join(data_path, file_path)
    print(path)
    df_day = pd.read_csv(path,lineterminator='\n')
    data_list.append(df_day)
df = pd.concat(data_list)
# Out:
# ['step2-output-ES-2020-02-01.csv', 'step2-output-ES-2020-02-04.csv', 'step2-output-ES-2020-02-05.csv', 'step2-output-ES-2020-02-06.csv', 'step2-output-ES-2020-02-09.csv', 'step2-output-ES-2020-02-10.csv', 'step2-output-ES-2020-02-11.csv', 'step2-output-ES-2020-02-14.csv', 'step2-output-ES-2020-02-16.csv', 'step2-output-ES-2020-02-17.csv', 'step2-output-ES-2020-02-20.csv', 'step2-output-ES-2020-02-21.csv', 'step2-output-ES-2020-02-22.csv', 'step2-output-ES-2020-02-27.csv', 'step2-output-ES-2020-02-29.csv']
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-01.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-04.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-05.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-06.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-09.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-10.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-11.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-14.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-16.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-17.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-20.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-21.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-22.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-27.csv
# D:\covid research\output\step 2 output\2020-02-es\step2-output-ES-2020-02-29.csv

# %%
df_date = df.copy(deep=True)
df_date['day'] = df_date['created_at'].apply(lambda x: x.split(' ')[0])
df_date['hour'] = df_date['created_at'].apply(lambda x: x.split(' ')[1])
df_date['hour'] = df_date['hour'].apply(lambda x: x.split('-')[0])
#start_date = '2020-03-' + '%.2d' % start
#end_date = '2020-03-' + '%.2d' % (end + 1)

#selected_date = (df_date['day'] != start_date) & (df_date['day'] != end_date)
df_01 = df_date.copy(deep=True)
df_01 = df_01.reset_index(drop=True)
day_count = df_01.groupby('day').count()['text']

# %% [markdown]
# # Preprocessing

# %%
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
df_01['text'] = df_01['text'].apply(lambda x: remove_emoji(x))
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df_01['text'] = df_01['text'].apply(lambda x: BeautifulSoup(x, "html.parser").get_text())
df_01['text'] = df_01['text'].apply(lambda x: re.sub('\[[^]]*\]', '', x))
df_01['text'] = df_01['text'].apply(lambda x: re.sub(r'http\S+', '', x))
df_01['text'] = df_01['text'].str.replace('[^\w\s]','')
import nltk
nltk.download('stopwords')
stop = set(stopwords.words('spanish'))
punctuation = list(string.punctuation)
stop.update(punctuation)
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
def remove_xml(text):
    return re.sub(r'<[^<]+?>', '', text)

def remove_newlines(text):
    return text.replace('\n', ' ') 
    

def remove_manyspaces(text):
    return re.sub(r'\s+', ' ', text)

def clean_text(text):
    text = remove_xml(text)
    text = remove_newlines(text)
    text = remove_manyspaces(text)
    return text
df_01['text']= df_01['text'].apply(clean_text)
df_02 = df_01.copy()
nlp = spacy.load('es_core_news_sm')
# lemmatizatioin using Spacy to count the appearance of each word
def space (comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df_02['text']= df_02['text'].apply(space)
df_02['text'].head(20)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0     rt amigosdelalexis inseguridad crecer impresio...
# 1                           rt chefleciav dinner corona
# 2     rt abc_es impactant imagen pekín desiertar cor...
# 3     rt ladydisorder ver reportaje chico ir edifici...
# 4     rt paumatalap hacer falta coronavirus extingar...
# 5                                elbueno_andrser saludo
# 6     rt pappo_17 uno gana ser cara roto jsjsjajo bu...
# 7     rt earisteguietar bueno nicola desastre vivir ...
# 8     rt ladydisorder ver reportaje chico ir edifici...
# 9     oms deber investigar mejor maduruscoñoesumadre...
# 10    hospital tanto lento si llegar catarro salir c...
# 11    rt instasamer ir hacer french  february partir...
# 12    buen día hoy día 20ºc 8ºc mínimo tiempo mostly...
# 13                  rt jastrunc coronavirus entrar país
# 14    buen día parte karpito disfrutón ayer vivi noc...
# 15    rt jb98luis alcorcón vivido menos 1 km ebola l...
# 16       rt gabocarvajalsw usted coronavirus bueno pase
# 17    rt viri_y_sebas2 bueno llegar 100 rt doctor am...
# 18                 sam300527 mejor dicho nunca buen día
# 19                       guardared do liverpool é bueno
# Name: text, dtype: object

# %% [markdown]
# # NRC

# %%
ncr = pd.read_excel("D:/covid research/src/local_exe/step 3/NRC-Emotion-Lexicon-v0.92-In105Languages-Nov2017Translations.xlsx")
ncr = ncr[['English (en)', 'Spanish (es)', 'Positive', 'Negative', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']]
ncr = ncr[ncr['Spanish (es)'] != 'NO TRANSLATION'].reset_index(drop=True)
emotions = ['Anger', 'Anticipation','Disgust','Fear', 'Joy','Sadness', 'Surprise', 'Trust']
def join_edited_string(edited_tweets):
    
    edited_string = ''
    for row in edited_tweets:
        edited_string = edited_string + ' ' + row
        
    return edited_string

joined_string = join_edited_string(df_01['text'])

tokens = joined_string.split(' ')

joined_string1 = join_edited_string(df_02['text'])
tokens1 = joined_string1.split(' ')

unique_words = set(tokens)
unique_words1 = set(tokens1)
unique_words.update(unique_words1)
word_to_ind = dict((word, i) for i, word in enumerate(unique_words))
ind_to_word = dict((i, word) for i, word in enumerate(unique_words))

# %%
import nltk
nltk.download('punkt')
from collections import defaultdict
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_tweets = df_01.copy(deep=True)
df_tweets1 = df_02.copy(deep=True)
emo_info = {'emotion':'' , 'emo_frq': defaultdict(int) }
list_emotion_counts = []
for emotion in emotions:
        emo_info = {}
        emo_info['emotion'] = emotion
        emo_info['emo_frq'] = defaultdict(int)
        list_emotion_counts.append(emo_info)
nrow = df_tweets.shape[0]
df_emotions = pd.DataFrame(0, index=df_tweets.index, columns=emotions)

# %%
process_count=0
for i in range(nrow):
        process_count+=1
        if process_count %100==0:
            print(process_count)
            print(df_tweets.loc[i])
        tweet = word_tokenize(df_tweets.loc[i]['text'], language='spanish')
        for word in tweet:
            word_stemmed = word
            result = ncr[ncr['Spanish (es)'] == word_stemmed]
            if not result.empty:
                # update the tweet-emotions counts
                for idx, emotion in enumerate(emotions):
                    df_emotions.at[i, emotion] += result[emotion].iloc[0]
                    # update the frequencies dictionary list
                    if result[emotion].iloc[0].any():
                        try:
                            list_emotion_counts[idx]['emo_frq'][word_to_ind[word]] += 1
                        except:
                            continue
            else:
                doc = nlp(word)
                word_stemmed1 = " ".join([token.lemma_ for token in doc]).lower()
                result1 = ncr[ncr['Spanish (es)'] == word_stemmed1]
                if not result1.empty:
                    # update the tweet-emotions counts
                    for idx, emotion in enumerate(emotions):
                        df_emotions.at[i, emotion] += result1[emotion].iloc[0]
                        # update the frequencies dictionary list
                        if result1[emotion].iloc[0].any():
                            try:
                                list_emotion_counts[idx]['emo_frq'][word_to_ind[word_stemmed1]] += 1
                            except:
                                continue
# Out:
# 100
# created_at                                      2020-02-02 01-27-47
# id_str                                          1223780017924165633
# text              rt dw_espanol china confirmó domingo 02022020 ...
# user              {'id': 151579616, 'id_str': '151579616', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Santos, Brasil
# country\r                                                  brasil\r
# day                                                      2020-02-02
# hour                                                             01
# Name: 99, dtype: object
# 200
# created_at                                      2020-02-01 16-46-46
# id_str                                          1223648899786772481
# text              rubenrobles13 buenos días dame oportunidad ver...
# user              {'id': 125761307, 'id_str': '125761307', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              México-Telmex
# country\r                                                  méxico\r
# day                                                      2020-02-01
# hour                                                             16
# Name: 199, dtype: object
# 300
# created_at                                      2020-02-01 20-30-23
# id_str                                          1223705174746763264
# text                desertnosoy paso insultarte vez bueno cbrazonzo
# user              {'id': 771814032034660358, 'id_str': '77181403...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Vallekas.
# country\r                                                  españa\r
# day                                                      2020-02-01
# hour                                                             20
# Name: 299, dtype: object
# 400
# created_at                                      2020-02-02 02-57-07
# id_str                                          1223802499393392640
# text              steelers tpolamalu missi_matthews profootballh...
# user              {'id': 304641238, 'id_str': '304641238', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     México
# country\r                                                  méxico\r
# day                                                      2020-02-02
# hour                                                             02
# Name: 399, dtype: object
# 500
# created_at                                      2020-02-01 20-09-55
# id_str                                          1223700024162443264
# text              rt naticleiva cdf lamentan diciendo tranquilid...
# user              {'id': 207470595, 'id_str': '207470595', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Curicó, Chile
# country\r                                                   chile\r
# day                                                      2020-02-01
# hour                                                             20
# Name: 499, dtype: object
# 600
# created_at                                      2020-02-02 05-01-03
# id_str                                          1223833688217047040
# text              ligabbvamx bueno narrador párese llorando narr...
# user              {'id': 4348953019, 'id_str': '4348953019', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                  Mexicali, Baja California
# country\r                                                  méxico\r
# day                                                      2020-02-02
# hour                                                             05
# Name: 599, dtype: object
# 700
# created_at                                      2020-02-01 23-21-17
# id_str                                          1223748183140065280
# text              rt indirectasrock siquiera decepciono sólo que...
# user              {'id': 1191404447966081026, 'id_str': '1191404...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Mérida
# country\r                                                  españa\r
# day                                                      2020-02-01
# hour                                                             23
# Name: 699, dtype: object
# 800
# created_at                                      2020-02-02 03-29-13
# id_str                                          1223810577597857793
# text              asusta corona virus hacen gárgaras fuentes cho...
# user              {'id': 921835747799388162, 'id_str': '92183574...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Nicaragua
# country\r                                               nicaragua\r
# day                                                      2020-02-02
# hour                                                             03
# Name: 799, dtype: object
# 900
# created_at                                      2020-02-02 00-11-08
# id_str                                          1223760728299130880
# text              rt sidorpotencia 1feb etiqueta día patriarebel...
# user              {'id': 139262563, 'id_str': '139262563', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Zulia, Venezuela
# country\r                                               venezuela\r
# day                                                      2020-02-02
# hour                                                             00
# Name: 899, dtype: object
# 1000
# created_at                                      2020-02-01 15-58-40
# id_str                                          1223636795029708800
# text                    rt joldiek demasiado bueno gente aprovechan
# user              {'id': 1046912497771565057, 'id_str': '1046912...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Yauco, Puerto Rico
# country\r                                           united states\r
# day                                                      2020-02-01
# hour                                                             15
# Name: 999, dtype: object
# 1100
# created_at                                      2020-02-02 02-09-43
# id_str                                          1223790570801373184
# text              buenos gustos mente abierta respetan critican ...
# user              {'id': 1223402962661277703, 'id_str': '1223402...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-02-02
# hour                                                             02
# Name: 1099, dtype: object
# 1200
# created_at                                      2020-02-01 21-51-24
# id_str                                          1223725563287916546
# text               chavistas retuit tuits si escualidos si buenos l
# user              {'id': 2900083954, 'id_str': '2900083954', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Venezuela
# country\r                                               venezuela\r
# day                                                      2020-02-01
# hour                                                             21
# Name: 1199, dtype: object
# 1300
# created_at                                      2020-02-01 18-24-40
# id_str                                          1223673537111695365
# text                     ineffablelyniel nilcobax nooo bueno estaaa
# user              {'id': 1033480191098667009, 'id_str': '1033480...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        T-A-F-A-M-A-A-V-L 💗
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             18
# Name: 1299, dtype: object
# 1400
# created_at                                      2020-02-01 21-33-31
# id_str                                          1223721062770323457
# text                       vieja durmiendo llegó bueno extrañaba ma
# user              {'id': 1068177767810953218, 'id_str': '1068177...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Buenos Aires, Argentina
# country\r                                               argentina\r
# day                                                      2020-02-01
# hour                                                             21
# Name: 1399, dtype: object
# 1500
# created_at                                      2020-02-01 23-55-35
# id_str                                          1223756815021686784
# text              rt m_palmeros desabasto consecuencia desicione...
# user              {'id': 2577735318, 'id_str': '2577735318', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Mexico
# country\r                                                  méxico\r
# day                                                      2020-02-01
# hour                                                             23
# Name: 1499, dtype: object
# 1600
# created_at                                      2020-02-02 02-18-57
# id_str                                          1223792894445867009
# text              marujatarre buenos sabor concentrado grandes r...
# user              {'id': 8844532, 'id_str': '8844532', 'name': '...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           Bogotá, Colombia
# country\r                                                colombia\r
# day                                                      2020-02-02
# hour                                                             02
# Name: 1599, dtype: object
# 1700
# created_at                                      2020-02-02 03-05-12
# id_str                                          1223804533609914368
# text              rt ssalud_mx comunicado técnico diario nuevo c...
# user              {'id': 282180969, 'id_str': '282180969', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Pachuca
# country\r                                                  méxico\r
# day                                                      2020-02-02
# hour                                                             03
# Name: 1699, dtype: object
# 1800
# created_at                                      2020-02-01 14-35-45
# id_str                                          1223615928337948674
# text              dejad tan buenos ser tan guapos deprimo verdad xd
# user              {'id': 1006623341309022208, 'id_str': '1006623...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Málaga-Alicante
# country\r                                                  españa\r
# day                                                      2020-02-01
# hour                                                             14
# Name: 1799, dtype: object
# 1900
# created_at                                      2020-02-01 16-10-17
# id_str                                          1223639718430232576
# text                               pau_auza oh bueno si selena dice
# user              {'id': 342127128, 'id_str': '342127128', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Emotional Hell
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             16
# Name: 1899, dtype: object
# 2000
# created_at                                      2020-02-01 17-13-39
# id_str                                          1223655665178218499
# text              rt kookiejoels bueno veo nadie hablando namjoo...
# user              {'id': 1695138703, 'id_str': '1695138703', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Chile
# country\r                                                   chile\r
# day                                                      2020-02-01
# hour                                                             17
# Name: 1999, dtype: object
# 2100
# created_at                                      2020-02-01 23-47-45
# id_str                                          1223754843711590400
# text                                          sosanuni mostré bueno
# user              {'id': 1323265110, 'id_str': '1323265110', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Villa Mercedes
# country\r                                               argentina\r
# day                                                      2020-02-01
# hour                                                             23
# Name: 2099, dtype: object
# 2200
# created_at                                      2020-02-01 19-42-28
# id_str                                          1223693116139401217
# text                                     inútil bueno si note dicho
# user              {'id': 802217617721323521, 'id_str': '80221761...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                 cuando tú esposa no ésta 🙊
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             19
# Name: 2199, dtype: object
# 2300
# created_at                                      2020-02-02 01-20-51
# id_str                                          1223778273076875269
# text              rt mamunia8 juandugarte22 jajajajajjajajjajajj...
# user              {'id': 1419838598, 'id_str': '1419838598', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Caracas, Venezuela
# country\r                                               venezuela\r
# day                                                      2020-02-02
# hour                                                             01
# Name: 2299, dtype: object
# 2400
# created_at                                      2020-02-01 09-17-26
# id_str                                          1223535821363519488
# text              rt alvarobotias buenosdias semana pasada dediq...
# user              {'id': 966781822800711680, 'id_str': '96678182...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                  El norte , como los Stark
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             09
# Name: 2399, dtype: object
# 2500
# created_at                                      2020-02-01 20-15-27
# id_str                                          1223701416671424512
# text              haciendo thread penomeco inglés alguien bola n...
# user              {'id': 997155544669589509, 'id_str': '99715554...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   ᵏʰʰ ᵏʳⁿᵇ
# country\r                                                       -\r
# day                                                      2020-02-01
# hour                                                             20
# Name: 2499, dtype: object
# 2600
# created_at                                      2020-02-04 12-21-36
# id_str                                          1224669332002787328
# text              rt anatomapatolog2 coronavirus dia 310000 pers...
# user              {'id': 2855960997, 'id_str': '2855960997', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Quito, Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-02-04
# hour                                                             12
# Name: 2599, dtype: object
# 2700
# created_at                                      2020-02-04 16-08-11
# id_str                                          1224726353569816576
# text              mira q vas tan bueno falta respeto q cagando b...
# user              {'id': 144019747, 'id_str': '144019747', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                     General pico, La Pampa
# country\r                                               argentina\r
# day                                                      2020-02-04
# hour                                                             16
# Name: 2699, dtype: object
# 2800
# created_at                                      2020-02-04 22-50-36
# id_str                                          1224827625048285184
# text              jotalopez1 seria bueno ver toda energía enfoca...
# user              {'id': 78171020, 'id_str': '78171020', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Aqui y allá
# country\r                                              costa rica\r
# day                                                      2020-02-04
# hour                                                             22
# Name: 2799, dtype: object
# 2900
# created_at                                      2020-02-04 23-32-35
# id_str                                          1224838190491525120
# text              rt albertto4vc virus corona vs coronavirus lai...
# user              {'id': 885266118990024705, 'id_str': '88526611...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Cantabria, España
# country\r                                                  españa\r
# day                                                      2020-02-04
# hour                                                             23
# Name: 2899, dtype: object
# 3000
# created_at                                      2020-02-05 01-51-57
# id_str                                          1224873263270105088
# text              rt ssaludatacama atención atacama sabes cómo p...
# user              {'id': 121884345, 'id_str': '121884345', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Huasco, Chile
# country\r                                                   chile\r
# day                                                      2020-02-05
# hour                                                             01
# Name: 2999, dtype: object
# 3100
# created_at                                      2020-02-04 14-02-42
# id_str                                          1224694774642487302
# text                             amol bueno confundió chris zabdiel
# user              {'id': 731007788, 'id_str': '731007788', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   cncomuch
# country\r                                                       -\r
# day                                                      2020-02-04
# hour                                                             14
# Name: 3099, dtype: object
# 3200
# created_at                                      2020-02-04 17-25-19
# id_str                                          1224745764821393415
# text                                         bueno cogemos peleamos
# user              {'id': 788083783, 'id_str': '788083783', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        la gran puta mierda
# country\r                                                       -\r
# day                                                      2020-02-04
# hour                                                             17
# Name: 3199, dtype: object
# 3300
# created_at                                      2020-02-04 17-26-23
# id_str                                          1224746033256828930
# text              rt saralebrel muertes españa coronavirus 2020 ...
# user              {'id': 379151187, 'id_str': '379151187', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Madrid
# country\r                                                  españa\r
# day                                                      2020-02-04
# hour                                                             17
# Name: 3299, dtype: object
# 3400
# created_at                                      2020-02-04 16-54-55
# id_str                                          1224738114394099712
# text              rt pizzarrap podemos hablar pelear bueno bue s...
# user              {'id': 3422458019, 'id_str': '3422458019', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   Paternal
# country\r                                                  france\r
# day                                                      2020-02-04
# hour                                                             16
# Name: 3399, dtype: object
# 3500
# created_at                                      2020-02-04 22-55-48
# id_str                                          1224828933645926400
# text              rt lagitanica9 patética sinvergüenza deshumani...
# user              {'id': 279373957, 'id_str': '279373957', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Madrid
# country\r                                                  españa\r
# day                                                      2020-02-04
# hour                                                             22
# Name: 3499, dtype: object
# 3600
# created_at                                      2020-02-05 06-45-35
# id_str                                          1224947158505476096
# text                                             dianarivers_ bueno
# user              {'id': 1052752704706174976, 'id_str': '1052752...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               Tus pulmones
# country\r                                                       -\r
# day                                                      2020-02-05
# hour                                                             06
# Name: 3599, dtype: object
# 3700
# created_at                                      2020-02-04 11-02-57
# id_str                                          1224649539061256198
# text              rt ukiokoungi si coronavirus llega méxico culp...
# user              {'id': 2896791965, 'id_str': '2896791965', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     México
# country\r                                                  méxico\r
# day                                                      2020-02-04
# hour                                                             11
# Name: 3699, dtype: object
# 3800
# created_at                                      2020-02-04 21-29-23
# id_str                                          1224807186196549639
# text              rt purpleloveplus sj v bueno yg jungkook rey j...
# user              {'id': 1101289662, 'id_str': '1101289662', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  venezuela
# country\r                                               venezuela\r
# day                                                      2020-02-04
# hour                                                             21
# Name: 3799, dtype: object
# 3900
# created_at                                      2020-02-04 22-17-24
# id_str                                          1224819269982216192
# text                      rt angeldmg pa mexicanos coronaviruschina
# user              {'id': 368192350, 'id_str': '368192350', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Mexico
# country\r                                                  méxico\r
# day                                                      2020-02-04
# hour                                                             22
# Name: 3899, dtype: object
# 4000
# created_at                                      2020-02-04 17-29-49
# id_str                                          1224746897245556736
# text              rt uninoticias oms actualiza cifras coronaviru...
# user              {'id': 831704187771592705, 'id_str': '83170418...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                 Pinar de la Calma, Zapopan
# country\r                                                  méxico\r
# day                                                      2020-02-04
# hour                                                             17
# Name: 3999, dtype: object
# 4100
# created_at                                      2020-02-04 09-08-02
# id_str                                          1224620619347742721
# text              activan control sanitario aeropuerto maiquetía...
# user              {'id': 920263298, 'id_str': '920263298', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Venezuela
# country\r                                               venezuela\r
# day                                                      2020-02-04
# hour                                                             09
# Name: 4099, dtype: object
# 4200
# created_at                                      2020-02-04 16-30-01
# id_str                                          1224731848099729411
# text              rt elmundoes doctor li wenliang detectó estudi...
# user              {'id': 326431455, 'id_str': '326431455', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                             En Sagitario-Carina Via Láctea
# country\r                                                       -\r
# day                                                      2020-02-04
# hour                                                             16
# Name: 4199, dtype: object
# 4300
# created_at                                      2020-02-04 20-51-23
# id_str                                          1224797623195926531
# text              pepeverderon lectura buenos económico regulare...
# user              {'id': 306891965, 'id_str': '306891965', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                     En la ciudad del Betis
# country\r                                                       -\r
# day                                                      2020-02-04
# hour                                                             20
# Name: 4299, dtype: object
# 4400
# created_at                                      2020-02-05 01-16-32
# id_str                                          1224864350361526272
# text              rabbitjichu ahbueno bigbrotherau teamlisa mepa...
# user              {'id': 974954868631851009, 'id_str': '97495486...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Itzy mamamoo y (G)I-DLE
# country\r                                                       -\r
# day                                                      2020-02-05
# hour                                                             01
# Name: 4399, dtype: object
# 4500
# created_at                                      2020-02-04 19-32-06
# id_str                                          1224777670854107136
# text              rt orllugoso escribir bein conoravirus higos p...
# user              {'id': 86975670, 'id_str': '86975670', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Gràcia
# country\r                                                  españa\r
# day                                                      2020-02-04
# hour                                                             19
# Name: 4499, dtype: object
# 4600
# created_at                                      2020-02-04 11-30-46
# id_str                                          1224656539367149568
# text              dominguezbrii bueeeeen diaaaaa ah bueno chau v...
# user              {'id': 1208600124915699713, 'id_str': '1208600...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-02-04
# hour                                                             11
# Name: 4599, dtype: object
# 4700
# created_at                                      2020-02-04 16-39-39
# id_str                                          1224734272394792960
# text              rt inversorperga provincia buenos aires cumple...
# user              {'id': 885695414942535680, 'id_str': '88569541...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                             Ciudad Autónoma de Buenos Aire
# country\r                                               argentina\r
# day                                                      2020-02-04
# hour                                                             16
# Name: 4699, dtype: object
# 4800
# created_at                                      2020-02-04 15-04-12
# id_str                                          1224710251645149184
# text              rt marcelomerkato bueno según fallo tas sanció...
# user              {'id': 1335466700, 'id_str': '1335466700', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Córdoba, Argentina
# country\r                                               argentina\r
# day                                                      2020-02-04
# hour                                                             15
# Name: 4799, dtype: object
# 4900
# created_at                                      2020-02-04 21-08-03
# id_str                                          1224801817491492865
# text              rt kansaita_ bueno voy gastar dinero total dar...
# user              {'id': 718816492859584512, 'id_str': '71881649...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Uruwhy 🇺🇾
# country\r                                                       -\r
# day                                                      2020-02-04
# hour                                                             21
# Name: 4899, dtype: object
# 5000
# created_at                                      2020-02-04 15-57-51
# id_str                                          1224723753113915398
# text                                 marsherams81 buenos días marce
# user              {'id': 100110218, 'id_str': '100110218', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     México
# country\r                                                  méxico\r
# day                                                      2020-02-04
# hour                                                             15
# Name: 4999, dtype: object
# 5100
# created_at                                      2020-02-04 23-33-48
# id_str                                          1224838496659148800
# text              rt enriquearce_ hecho noche valencia bueno mej...
# user              {'id': 382752693, 'id_str': '382752693', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Castellón
# country\r                                                  españa\r
# day                                                      2020-02-04
# hour                                                             23
# Name: 5099, dtype: object
# 5200
# created_at                                      2020-02-05 20-41-34
# id_str                                          1225157540583002115
# text              ver crucero 3711 pasajeros cuarentena coronavi...
# user              {'id': 1442923200, 'id_str': '1442923200', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                               CL-CA-US-AU-ESP-FR-JP-RS-CHN
# country\r                                                       -\r
# day                                                      2020-02-05
# hour                                                             20
# Name: 5199, dtype: object
# 5300
# created_at                                      2020-02-06 03-43-30
# id_str                                          1225263723595649024
# text              rt antonio57968224 china coronavirus polombia ...
# user              {'id': 568102557, 'id_str': '568102557', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Neiva
# country\r                                                colombia\r
# day                                                      2020-02-06
# hour                                                             03
# Name: 5299, dtype: object
# 5400
# created_at                                      2020-02-05 10-30-52
# id_str                                          1225003852895870976
# text              manu7coronas juanjoband24 mismo criticaban pso...
# user              {'id': 4835219493, 'id_str': '4835219493', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     España
# country\r                                                  españa\r
# day                                                      2020-02-05
# hour                                                             10
# Name: 5399, dtype: object
# 5500
# created_at                                      2020-02-05 15-25-32
# id_str                                          1225078008194584578
# text              coronavirus científicos unen multiplican esfue...
# user              {'id': 725333938789568513, 'id_str': '72533393...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                 Lima, Peru
# country\r                                                    perú\r
# day                                                      2020-02-05
# hour                                                             15
# Name: 5499, dtype: object
# 5600
# created_at                                      2020-02-06 04-28-19
# id_str                                          1225275002062286848
# text              rt alertanews24 urgente coronavirus taiwan anu...
# user              {'id': 3026223222, 'id_str': '3026223222', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Santa Tecla
# country\r                                             el salvador\r
# day                                                      2020-02-06
# hour                                                             04
# Name: 5599, dtype: object
# 5700
# created_at                                      2020-02-05 23-25-32
# id_str                                          1225198804166729728
# text              rt davycoen1 quería resaltar esparcialmente pá...
# user              {'id': 164407049, 'id_str': '164407049', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# ...
# text              rt lord_inario tan cierto si asiste persona sí...
# user              {'id': 1175581870001725440, 'id_str': '1175581...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Chilangolandia
# country\r                                                       -\r
# day                                                      2020-03-01
# hour                                                             03
# Name: 35399, dtype: object
# 35500
# created_at                                      2020-03-01 00-35-46
# id_str                                          1233913787733991426
# text              seguimeytesigo felizsabado buensabado siganmel...
# user              {'id': 1223260801030656003, 'id_str': '1223260...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Pinamar, Argentina
# country\r                                               argentina\r
# day                                                      2020-03-01
# hour                                                             00
# Name: 35499, dtype: object
# 35600
# created_at                                      2020-02-29 19-46-46
# id_str                                          1233841058498449412
# text              rt ecuadorplay negligencia paciente coronaviru...
# user              {'id': 437706939, 'id_str': '437706939', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Guayaquil
# country\r                                                 ecuador\r
# day                                                      2020-02-29
# hour                                                             19
# Name: 35599, dtype: object
# 35700
# created_at                                      2020-02-29 17-46-22
# id_str                                          1233810758850531329
# text              chiapas inmediatamente primer caso coronavirus...
# user              {'id': 495385264, 'id_str': '495385264', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                       CDMX
# country\r                                                  méxico\r
# day                                                      2020-02-29
# hour                                                             17
# Name: 35699, dtype: object
# 35800
# created_at                                      2020-02-29 18-33-09
# id_str                                          1233822532257665030
# text              rt lfbghb si tomaste balde mezcla barra bolich...
# user              {'id': 2337084950, 'id_str': '2337084950', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Córdoba, Argentina
# country\r                                               argentina\r
# day                                                      2020-02-29
# hour                                                             18
# Name: 35799, dtype: object
# 35900
# created_at                                      2020-02-29 18-32-07
# id_str                                          1233822272223424512
# text              rt fernavarro17 monumento señora ídola coronav...
# user              {'id': 361149714, 'id_str': '361149714', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Manresa
# country\r                                                  españa\r
# day                                                      2020-02-29
# hour                                                             18
# Name: 35899, dtype: object
# 36000
# created_at                                      2020-02-29 18-41-54
# id_str                                          1233824734279819266
# text              rt tecnm_mx eltecnminforma conoce síntomas pro...
# user              {'id': 467624923, 'id_str': '467624923', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                      Morelia, Mich. México
# country\r                                                  méxico\r
# day                                                      2020-02-29
# hour                                                             18
# Name: 35999, dtype: object
# 36100
# created_at                                      2020-02-29 17-23-15
# id_str                                          1233804941367660545
# text              rt antoniornaranjo madre hace minutos si cojo ...
# user              {'id': 2353421615, 'id_str': '2353421615', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   Tabarnia
# country\r                                                       -\r
# day                                                      2020-02-29
# hour                                                             17
# Name: 36099, dtype: object
# 36200
# created_at                                      2020-02-29 21-17-16
# id_str                                          1233863833556520962
# text              rt lahistoriaec gobierno habilita 171 posibles...
# user              {'id': 756684925168943104, 'id_str': '75668492...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Quito, Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-02-29
# hour                                                             21
# Name: 36199, dtype: object
# 36300
# created_at                                      2020-03-01 06-56-20
# id_str                                          1234009560484110337
# text              rt ag20719260 primer muerte coronavirus tailan...
# user              {'id': 256726215, 'id_str': '256726215', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                               En un lugar de este planeta.
# country\r                                                       -\r
# day                                                      2020-03-01
# hour                                                             06
# Name: 36299, dtype: object
# 36400
# created_at                                      2020-02-29 14-01-41
# id_str                                          1233754215429722113
# text              rt drhuerta 13 confirman coronavirus origen de...
# user              {'id': 118570939, 'id_str': '118570939', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Limaaa // Peru 🇵🇪
# country\r                                                       -\r
# day                                                      2020-02-29
# hour                                                             14
# Name: 36399, dtype: object
# 36500
# created_at                                      2020-02-29 15-50-53
# id_str                                          1233781696522117122
# text              rt chayrairma1 méxico único país presidente re...
# user              {'id': 42559022, 'id_str': '42559022', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                México City
# country\r                                                  méxico\r
# day                                                      2020-02-29
# hour                                                             15
# Name: 36499, dtype: object
# 36600
# created_at                                      2020-02-29 17-16-42
# id_str                                          1233803293001953280
# text              ósea si entienden coronavirus personas brote e...
# user              {'id': 111364285, 'id_str': '111364285', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     mexico
# country\r                                                  méxico\r
# day                                                      2020-02-29
# hour                                                             17
# Name: 36599, dtype: object
# 36700
# created_at                                      2020-02-29 20-43-51
# id_str                                          1233855423977021441
# text              rt mundialessin fuerte sospecha papa infectado...
# user              {'id': 905858636290936833, 'id_str': '90585863...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                               San Miguel Petapa, Guatemala
# country\r                                               guatemala\r
# day                                                      2020-02-29
# hour                                                             20
# Name: 36699, dtype: object
# 36800
# created_at                                      2020-03-01 03-48-15
# id_str                                          1233962227767619589
# text              georgeartwell perdí cosas toda esperanza bueno...
# user              {'id': 1662476803, 'id_str': '1662476803', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               En el exilio
# country\r                                                       -\r
# day                                                      2020-03-01
# hour                                                             03
# Name: 36799, dtype: object
# 36900
# created_at                                      2020-03-01 02-01-21
# id_str                                          1233935325468200962
# text              rt katuarkonada investigando vacuna coronaviru...
# user              {'id': 2975892801, 'id_str': '2975892801', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Venezuela
# country\r                                               venezuela\r
# day                                                      2020-03-01
# hour                                                             02
# Name: 36899, dtype: object
# 37000
# created_at                                      2020-03-01 05-08-09
# id_str                                          1233982335240089600
# text              rt censida medidas prevención covid19 coronavi...
# user              {'id': 410679474, 'id_str': '410679474', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     México
# country\r                                                  méxico\r
# day                                                      2020-03-01
# hour                                                             05
# Name: 36999, dtype: object
# 37100
# created_at                                      2020-02-29 20-48-04
# id_str                                          1233856485156933633
# text              rt reynadaniela buenos aires argentina hace 3 ...
# user              {'id': 892024975128920064, 'id_str': '89202497...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                           CABA, Argentina
# country\r                                               argentina\r
# day                                                      2020-02-29
# hour                                                             20
# Name: 37099, dtype: object
# 37200
# created_at                                      2020-03-01 00-18-31
# id_str                                          1233909446616633345
# text               españa registra medio centenar casos coronavirus
# user              {'id': 987261727, 'id_str': '987261727', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       Vilagarcía de Arousa
# country\r                                                  españa\r
# day                                                      2020-03-01
# hour                                                             00
# Name: 37199, dtype: object

# %%
df_tweets = pd.concat([df_tweets, df_emotions], axis=1)

# %%
df_tweets.to_csv(r"D:\covid research\output\step 3 output\2020-02-ES.csv")
