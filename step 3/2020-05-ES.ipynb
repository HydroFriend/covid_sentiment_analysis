# %%
import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


from nltk.corpus import stopwords

from tqdm import tqdm
import os
import nltk
import spacy
spacy.require_gpu()
import random
from spacy.util import compounding
from spacy.util import minibatch

import warnings
warnings.filterwarnings("ignore")

from bs4 import BeautifulSoup

from datetime import date
# Out:
# c:\Users\hydro\anaconda3\envs\cov\lib\site-packages\cupy\_environment.py:205: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   warnings.warn(

# %%
data_path = r"D:\covid research\output\step 2 output\2020-05-es"
days=os.listdir(data_path)
# days =[ i for i in days if i.split('.')[0].split('-')[-1]=='es']
print(days)

data_list = []
for i in days:
    file_path  = i
    path = os.path.join(data_path, file_path)
    print(path)
    df_day = pd.read_csv(path,lineterminator='\n')
    data_list.append(df_day)
df = pd.concat(data_list)
# Out:
# ['step2-output-ES-2020-05-01.csv', 'step2-output-ES-2020-05-02.csv', 'step2-output-ES-2020-05-03.csv', 'step2-output-ES-2020-05-04.csv', 'step2-output-ES-2020-05-05.csv', 'step2-output-ES-2020-05-06.csv', 'step2-output-ES-2020-05-07.csv', 'step2-output-ES-2020-05-08.csv', 'step2-output-ES-2020-05-09.csv', 'step2-output-ES-2020-05-10.csv', 'step2-output-ES-2020-05-11.csv', 'step2-output-ES-2020-05-12.csv', 'step2-output-ES-2020-05-13.csv', 'step2-output-ES-2020-05-14.csv', 'step2-output-ES-2020-05-15.csv', 'step2-output-ES-2020-05-16.csv', 'step2-output-ES-2020-05-17.csv', 'step2-output-ES-2020-05-18.csv', 'step2-output-ES-2020-05-19.csv', 'step2-output-ES-2020-05-20.csv', 'step2-output-ES-2020-05-21.csv', 'step2-output-ES-2020-05-22.csv', 'step2-output-ES-2020-05-23.csv', 'step2-output-ES-2020-05-26.csv', 'step2-output-ES-2020-05-27.csv', 'step2-output-ES-2020-05-28.csv', 'step2-output-ES-2020-05-29.csv', 'step2-output-ES-2020-05-30.csv', 'step2-output-ES-2020-05-31.csv']
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-01.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-02.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-03.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-04.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-05.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-06.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-07.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-08.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-09.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-10.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-11.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-12.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-13.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-14.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-15.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-16.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-17.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-18.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-19.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-20.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-21.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-22.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-23.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-26.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-27.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-28.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-29.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-30.csv
# D:\covid research\output\step 2 output\2020-05-es\step2-output-ES-2020-05-31.csv

# %%
df_date = df.copy(deep=True)
df_date['day'] = df_date['created_at'].apply(lambda x: x.split(' ')[0])
df_date['hour'] = df_date['created_at'].apply(lambda x: x.split(' ')[1])
df_date['hour'] = df_date['hour'].apply(lambda x: x.split('-')[0])
#start_date = '2020-03-' + '%.2d' % start
#end_date = '2020-03-' + '%.2d' % (end + 1)

#selected_date = (df_date['day'] != start_date) & (df_date['day'] != end_date)
df_01 = df_date.copy(deep=True)
df_01 = df_01.reset_index(drop=True)
day_count = df_01.groupby('day').count()['text']

# %% [markdown]
# # Preprocessing

# %%
from nltk.corpus import stopwords
from wordcloud import WordCloud, STOPWORDS
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
df_01['text'] = df_01['text'].apply(lambda x: remove_emoji(x))
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df_01['text'] = df_01['text'].apply(lambda x: BeautifulSoup(x, "html.parser").get_text())
df_01['text'] = df_01['text'].apply(lambda x: re.sub('\[[^]]*\]', '', x))
df_01['text'] = df_01['text'].apply(lambda x: re.sub(r'http\S+', '', x))
df_01['text'] = df_01['text'].str.replace('[^\w\s]','')
import nltk
nltk.download('stopwords')
stop = set(stopwords.words('spanish'))
punctuation = list(string.punctuation)
stop.update(punctuation)
df_01['text'] = df_01['text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
def remove_xml(text):
    return re.sub(r'<[^<]+?>', '', text)

def remove_newlines(text):
    return text.replace('\n', ' ') 
    

def remove_manyspaces(text):
    return re.sub(r'\s+', ' ', text)

def clean_text(text):
    text = remove_xml(text)
    text = remove_newlines(text)
    text = remove_manyspaces(text)
    return text
df_01['text']= df_01['text'].apply(clean_text)
df_02 = df_01.copy()
nlp = spacy.load('es_core_news_sm')
# lemmatizatioin using Spacy to count the appearance of each word
def space (comment):
    doc = nlp(comment)
    return " ".join([token.lemma_ for token in doc])
df_02['text']= df_02['text'].apply(space)
df_02['text'].head(20)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 0     crear río janeiro cementerio vertical apilar a...
# 1     rt corponespartir reporte nuevaesparta aplicad...
# 2     rt europapress cifrar persona recuperado coron...
# 3     carmencalvo _ 19 mujer violencia casi 30000 co...
# 4     decir mañana poner rolo alguno musical marthad...
# 5     rt frayjosepho pandemia horror aspecto positiv...
# 6     rt heliodoptero columna alejandro muñoz dr álv...
# 7                           primero ganar covid19 ahora
# 8     corte 1900 hora jueves 30 abril méxico 19 mil ...
# 9     rt rioscorona1 personal salud listo preparado ...
# 10    radiorelojcubar 1rodemayofidelista combatiente...
# 11    rt edomex ayuda reducir número contagio covid_...
# 12    rt muna_bargar julia 5 año si coronavirus ojo ...
# 13    rt coronavirusnewv illinois illinois hoy caso ...
# 14    rt mascaras_covid organización dedicado fabric...
# 15    rt bosslogisticsi1 80 población convencido buk...
# 16    rt politicomx médico alemán protestar desnudo ...
# 17    rt osoriochong informo realizar prueba covid19...
# 18    científico corea sur asegurar persona poder in...
# 19                    rt marcovillalba5 odio coronaviru
# Name: text, dtype: object

# %% [markdown]
# # NRC

# %%
ncr = pd.read_excel("D:/covid research/src/local_exe/step 3/NRC-Emotion-Lexicon-v0.92-In105Languages-Nov2017Translations.xlsx")
ncr = ncr[['English (en)', 'Spanish (es)', 'Positive', 'Negative', 'Anger', 'Anticipation', 'Disgust', 'Fear', 'Joy', 'Sadness', 'Surprise', 'Trust']]
ncr = ncr[ncr['Spanish (es)'] != 'NO TRANSLATION'].reset_index(drop=True)
emotions = ['Anger', 'Anticipation','Disgust','Fear', 'Joy','Sadness', 'Surprise', 'Trust']
def join_edited_string(edited_tweets):
    
    edited_string = ''
    for row in edited_tweets:
        edited_string = edited_string + ' ' + row
        
    return edited_string

joined_string = join_edited_string(df_01['text'])

tokens = joined_string.split(' ')

joined_string1 = join_edited_string(df_02['text'])
tokens1 = joined_string1.split(' ')

unique_words = set(tokens)
unique_words1 = set(tokens1)
unique_words.update(unique_words1)
word_to_ind = dict((word, i) for i, word in enumerate(unique_words))
ind_to_word = dict((i, word) for i, word in enumerate(unique_words))

# %%
import nltk
nltk.download('punkt')
from collections import defaultdict
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hydro\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df_tweets = df_01.copy(deep=True)
df_tweets1 = df_02.copy(deep=True)
emo_info = {'emotion':'' , 'emo_frq': defaultdict(int) }
list_emotion_counts = []
for emotion in emotions:
        emo_info = {}
        emo_info['emotion'] = emotion
        emo_info['emo_frq'] = defaultdict(int)
        list_emotion_counts.append(emo_info)
nrow = df_tweets.shape[0]
df_emotions = pd.DataFrame(0, index=df_tweets.index, columns=emotions)

# %%
process_count=0
for i in range(nrow):
        process_count+=1
        if process_count %100==0:
            print(process_count)
            print(df_tweets.loc[i])
        tweet = word_tokenize(df_tweets.loc[i]['text'], language='spanish')
        for word in tweet:
            word_stemmed = word
            result = ncr[ncr['Spanish (es)'] == word_stemmed]
            if not result.empty:
                # update the tweet-emotions counts
                for idx, emotion in enumerate(emotions):
                    df_emotions.at[i, emotion] += result[emotion].iloc[0]
                    # update the frequencies dictionary list
                    if result[emotion].iloc[0].any():
                        try:
                            list_emotion_counts[idx]['emo_frq'][word_to_ind[word]] += 1
                        except:
                            continue
            else:
                doc = nlp(word)
                word_stemmed1 = " ".join([token.lemma_ for token in doc]).lower()
                result1 = ncr[ncr['Spanish (es)'] == word_stemmed1]
                if not result1.empty:
                    # update the tweet-emotions counts
                    for idx, emotion in enumerate(emotions):
                        df_emotions.at[i, emotion] += result1[emotion].iloc[0]
                        # update the frequencies dictionary list
                        if result1[emotion].iloc[0].any():
                            try:
                                list_emotion_counts[idx]['emo_frq'][word_to_ind[word_stemmed1]] += 1
                            except:
                                continue
# Out:
# 100
# created_at                                      2020-05-01 14-43-43
# id_str                                          1256232841140146183
# text              rt gerardodeicaza dilema hacer elecciones tiem...
# user              {'id': 3087266547, 'id_str': '3087266547', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Quito
# country\r                                                 ecuador\r
# day                                                      2020-05-01
# hour                                                             14
# Name: 99, dtype: object
# 200
# created_at                                      2020-05-01 09-44-54
# id_str                                          1256157641442803713
# text              españoles incluir fuerzas cuerpos seguridad gr...
# user              {'id': 441022981, 'id_str': '441022981', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                     Islas Canarias, España
# country\r                                                  españa\r
# day                                                      2020-05-01
# hour                                                             09
# Name: 199, dtype: object
# 300
# created_at                                      2020-05-01 13-40-17
# id_str                                          1256216877623398402
# text              protección ciudadana sigue previniendo covid19...
# user              {'id': 4285074442, 'id_str': '4285074442', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                      La Capital, Argentina
# country\r                                               argentina\r
# day                                                      2020-05-01
# hour                                                             13
# Name: 299, dtype: object
# 400
# created_at                                      2020-05-02 02-21-19
# id_str                                          1256408397940953094
# text              rt goberzamora covid_19 pandemia afectando mun...
# user              {'id': 1166545833610883073, 'id_str': '1166545...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         El Pangui, Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-05-02
# hour                                                             02
# Name: 399, dtype: object
# 500
# created_at                                      2020-05-01 13-59-40
# id_str                                          1256221755607302145
# text              rt krosolamente hoy 8 fuckings horas máscara t...
# user              {'id': 836401978884440064, 'id_str': '83640197...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Rosario, Argentina
# country\r                                               argentina\r
# day                                                      2020-05-01
# hour                                                             13
# Name: 499, dtype: object
# 600
# created_at                                      2020-05-01 14-48-56
# id_str                                          1256234153953165313
# text              1ero mayo unidos cubanos batalla frente pandem...
# user              {'id': 1136685432278794240, 'id_str': '1136685...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  La Habana
# country\r                                                    cuba\r
# day                                                      2020-05-01
# hour                                                             14
# Name: 599, dtype: object
# 700
# created_at                                      2020-05-01 23-00-16
# id_str                                          1256357802022486017
# text              través whatsapp puedes informarte aclarar duda...
# user              {'id': 238313302, 'id_str': '238313302', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                  Chilpancingo de los Bravo
# country\r                                                  méxico\r
# day                                                      2020-05-01
# hour                                                             23
# Name: 699, dtype: object
# 800
# created_at                                      2020-05-01 12-54-49
# id_str                                          1256205435541032960
# text              rt cntinforma emergencia covid19 detiene traba...
# user              {'id': 1247206021317234689, 'id_str': '1247206...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-05-01
# hour                                                             12
# Name: 799, dtype: object
# 900
# created_at                                      2020-05-01 18-40-20
# id_str                                          1256292387682422785
# text              rt bbcmundo coronavirus peter ratcliffe nobel ...
# user              {'id': 3410300872, 'id_str': '3410300872', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                Madrid, Comunidad de Madrid
# country\r                                                  españa\r
# day                                                      2020-05-01
# hour                                                             18
# Name: 899, dtype: object
# 1000
# created_at                                      2020-05-01 19-48-11
# id_str                                          1256309462689648640
# text                                       neta dan cuenta pandemia
# user              {'id': 2154076608, 'id_str': '2154076608', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                      Monterrey, Nuevo León
# country\r                                                  méxico\r
# day                                                      2020-05-01
# hour                                                             19
# Name: 999, dtype: object
# 1100
# created_at                                      2020-05-01 10-18-12
# id_str                                          1256166021695787008
# text              rt clarincom coronavirus argentina otorgaron p...
# user              {'id': 2900773582, 'id_str': '2900773582', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                       Caba
# country\r                                               argentina\r
# day                                                      2020-05-01
# hour                                                             10
# Name: 1099, dtype: object
# 1200
# created_at                                      2020-05-01 20-29-15
# id_str                                          1256319797442179072
# text              rt navedelmisterio atención abrimos encuesta n...
# user              {'id': 67988739, 'id_str': '67988739', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Corregidora, Qro México
# country\r                                                  méxico\r
# day                                                      2020-05-01
# hour                                                             20
# Name: 1199, dtype: object
# 1300
# created_at                                      2020-05-01 19-20-34
# id_str                                          1256302512736546819
# text              rt markocortes vez aprovechan pandemia benefic...
# user              {'id': 216153868, 'id_str': '216153868', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       Teocaltiche, Jalisco
# country\r                                                  méxico\r
# day                                                      2020-05-01
# hour                                                             19
# Name: 1299, dtype: object
# 1400
# created_at                                      2020-05-01 14-17-59
# id_str                                          1256226365147361281
# text              rccinformando coronavirusenperú antamina confi...
# user              {'id': 3355138529, 'id_str': '3355138529', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                Tacna, Peru
# country\r                                                    perú\r
# day                                                      2020-05-01
# hour                                                             14
# Name: 1399, dtype: object
# 1500
# created_at                                      2020-05-01 10-38-28
# id_str                                          1256171121965182976
# text              rt rafael_delrosal desescaladacoronavirus conj...
# user              {'id': 146897718, 'id_str': '146897718', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Málaga, Andalucía
# country\r                                                  españa\r
# day                                                      2020-05-01
# hour                                                             10
# Name: 1499, dtype: object
# 1600
# created_at                                      2020-05-01 15-01-18
# id_str                                          1256237266147688449
# text              rt warkentin alexandra representa resuelvan co...
# user              {'id': 2975747422, 'id_str': '2975747422', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       Huixquilucan, México
# country\r                                                  méxico\r
# day                                                      2020-05-01
# hour                                                             15
# Name: 1599, dtype: object
# 1700
# created_at                                      2020-05-01 18-53-17
# id_str                                          1256295646652481537
# text              aclista1 xriusenoticies enoticiescat puigdemon...
# user              {'id': 1194267037364867072, 'id_str': '1194267...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          San Francisco, CA
# country\r                                           united states\r
# day                                                      2020-05-01
# hour                                                             18
# Name: 1699, dtype: object
# 1800
# created_at                                      2020-05-01 17-00-00
# id_str                                          1256267137976373248
# text              consiste cuarentena cuidémonosentretodos coron...
# user              {'id': 153825949, 'id_str': '153825949', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Chile
# country\r                                                   chile\r
# day                                                      2020-05-01
# hour                                                             17
# Name: 1799, dtype: object
# 1900
# created_at                                      2020-05-02 02-46-57
# id_str                                          1256414848772120577
# text                  chumeltorres tu_imss mame mame mame covid__19
# user              {'id': 364365734, 'id_str': '364365734', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    rotando
# country\r                                                  brasil\r
# day                                                      2020-05-02
# hour                                                             02
# Name: 1899, dtype: object
# 2000
# created_at                                      2020-05-01 09-12-30
# id_str                                          1256149487724216320
# text              rt vpitv primer ministro rusia da positivo cov...
# user              {'id': 935679470865920002, 'id_str': '93567947...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                 Maracaibo- Zulia-Venezuela
# country\r                                               venezuela\r
# day                                                      2020-05-01
# hour                                                             09
# Name: 1999, dtype: object
# 2100
# created_at                                      2020-05-02 04-59-51
# id_str                                          1256448294139633665
# text              rt el_universal_mx oms afirmó origen covid19 c...
# user              {'id': 290805400, 'id_str': '290805400', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Xalapa
# country\r                                                  méxico\r
# day                                                      2020-05-02
# hour                                                             04
# Name: 2099, dtype: object
# 2200
# created_at                                      2020-05-01 14-35-18
# id_str                                          1256230723029172225
# text              rt csantiago19 sinaguaparquecaiza sinaguaturum...
# user              {'id': 170703235, 'id_str': '170703235', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                              Mun. Sucre, Caracas Venezuela
# country\r                                                       -\r
# day                                                      2020-05-01
# hour                                                             14
# Name: 2199, dtype: object
# 2300
# created_at                                      2020-05-01 16-08-53
# id_str                                          1256254274050371585
# text              rt reuterslatam organización mundial salud oms...
# user              {'id': 858509415523250176, 'id_str': '85850941...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                              la Patria Grande. Venezuela.
# country\r                                                       -\r
# day                                                      2020-05-01
# hour                                                             16
# Name: 2299, dtype: object
# 2400
# created_at                                      2020-05-02 00-06-01
# id_str                                          1256374348564267013
# text              rt eduardo_shaw imagen lamentable si escuchan ...
# user              {'id': 4433105121, 'id_str': '4433105121', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Montevideo, Uruguay
# country\r                                                 uruguay\r
# day                                                      2020-05-02
# hour                                                             00
# Name: 2399, dtype: object
# 2500
# created_at                                      2020-05-02 00-51-32
# id_str                                          1256385803216998400
# text              rt dw_espanol últimas noticias covid19 precio ...
# user              {'id': 370529938, 'id_str': '370529938', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                el salvador
# country\r                                             el salvador\r
# day                                                      2020-05-02
# hour                                                             00
# Name: 2499, dtype: object
# 2600
# created_at                                      2020-05-01 11-42-17
# id_str                                          1256187181963632640
# text              coronavirus argentina masivo cacerolazo nacion...
# user              {'id': 400054955, 'id_str': '400054955', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                               BUENOS AIRES
# country\r                                               argentina\r
# day                                                      2020-05-01
# hour                                                             11
# Name: 2599, dtype: object
# 2700
# created_at                                      2020-05-01 13-34-20
# id_str                                          1256215380252647426
# text              rt cope médicos uci alertan 30 falsos negativo...
# user              {'id': 139718484, 'id_str': '139718484', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Valencia (España).
# country\r                                                  españa\r
# day                                                      2020-05-01
# hour                                                             13
# Name: 2699, dtype: object
# 2800
# created_at                                      2020-05-01 23-04-46
# id_str                                          1256358934505553922
# text              reportecovid19 1 mayo confirmamos colombia min...
# user              {'id': 3298087153, 'id_str': '3298087153', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                      Cali, Valle del Cauca
# country\r                                                colombia\r
# day                                                      2020-05-01
# hour                                                             23
# Name: 2799, dtype: object
# 2900
# created_at                                      2020-05-01 17-32-00
# id_str                                          1256275191035985921
# text              rt conelmazodando dirán ahora hombres armados ...
# user              {'id': 630293817, 'id_str': '630293817', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                 Venezolana y CHAVISTA 100%
# country\r                                                       -\r
# day                                                      2020-05-01
# hour                                                             17
# Name: 2899, dtype: object
# 3000
# created_at                                      2020-05-01 18-09-03
# id_str                                          1256284514973868035
# text              publicado episodio ivoox 01052020 mensaje leni...
# user              {'id': 2274823081, 'id_str': '2274823081', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Quito
# country\r                                                 ecuador\r
# day                                                      2020-05-01
# hour                                                             18
# Name: 2999, dtype: object
# 3100
# created_at                                      2020-05-01 18-46-30
# id_str                                          1256293939562393600
# text              rt javiernavia recuerdo diadeltrabajador mayor...
# user              {'id': 2424671376, 'id_str': '2424671376', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                      San Salvador de Jujuy
# country\r                                               argentina\r
# day                                                      2020-05-01
# hour                                                             18
# Name: 3099, dtype: object
# 3200
# created_at                                      2020-05-01 17-00-48
# id_str                                          1256267339290550278
# text              canarias llevará cabo muchísimos controles pue...
# user              {'id': 115987338, 'id_str': '115987338', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     España
# country\r                                                  españa\r
# day                                                      2020-05-01
# hour                                                             17
# Name: 3199, dtype: object
# 3300
# created_at                                      2020-05-01 15-02-02
# id_str                                          1256237450697027585
# text              rt ugt_andalucia vamos permitir derechos labor...
# user              {'id': 1062980766, 'id_str': '1062980766', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                Córdoba, Andalucía, España
# country\r                                                  españa\r
# day                                                      2020-05-01
# hour                                                             15
# Name: 3299, dtype: object
# 3400
# created_at                                      2020-05-01 12-11-43
# id_str                                          1256194589083525120
# text              titulares médicos querétaro covid19 dados alta...
# user              {'id': 2432423784, 'id_str': '2432423784', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Querétaro
# country\r                                                  méxico\r
# day                                                      2020-05-01
# hour                                                             12
# Name: 3399, dtype: object
# 3500
# created_at                                      2020-05-01 20-11-25
# id_str                                          1256315309541265409
# text              rt melenaperezjaen ahora covid__19 vino anillo...
# user              {'id': 1357889886, 'id_str': '1357889886', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            GUADALAJARA JAL
# country\r                                                  méxico\r
# day                                                      2020-05-01
# hour                                                             20
# Name: 3499, dtype: object
# 3600
# created_at                                      2020-05-01 19-37-47
# id_str                                          1256306845452365824
# text                              rt marcovillalba5 odio coronaviru
# user              {'id': 251444731, 'id_str': '251444731', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   colombia
# country\r                                                colombia\r
# day                                                      2020-05-01
# hour                                                             19
# Name: 3599, dtype: object
# 3700
# created_at                                      2020-05-01 09-56-26
# id_str                                          1256160543913775105
# text              platos rotos pandemia empezado pagar siempre p...
# user              {'id': 385438849, 'id_str': '385438849', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            Zaragoza España
# country\r                                                  españa\r
# day                                                      2020-05-01
# hour                                                             09
# Name: 3699, dtype: object
# 3800
# created_at                                      2020-05-01 19-00-37
# id_str                                          1256297492121112577
# text              rt informa_ec españa autoridades sanitarias in...
# user              {'id': 1215429935134846976, 'id_str': '1215429...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Ecuador
# country\r                                                 ecuador\r
# day                                                      2020-05-01
# hour                                                             19
# Name: 3799, dtype: object
# 3900
# created_at                                      2020-05-01 09-38-30
# id_str                                          1256156030830026752
# text              rt edugaresp pandemia muestra baja calidad emp...
# user              {'id': 1243694612, 'id_str': '1243694612', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                      Earth
# country\r                                           united states\r
# day                                                      2020-05-01
# hour                                                             09
# Name: 3899, dtype: object
# 4000
# created_at                                      2020-05-01 15-25-32
# id_str                                          1256243364644691969
# text              rt jvwolfersdorff marenas imfdchile congelar p...
# user              {'id': 289693058, 'id_str': '289693058', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                            La Reina, Chile
# country\r                                                   chile\r
# day                                                      2020-05-01
# hour                                                             15
# Name: 3999, dtype: object
# 4100
# created_at                                      2020-05-02 10-34-14
# id_str                                          1256532444469252097
# text              rt cmgorriaran tres días alarma calviño declar...
# user              {'id': 2512506036, 'id_str': '2512506036', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     MADRID
# country\r                                                  españa\r
# day                                                      2020-05-02
# hour                                                             10
# Name: 4099, dtype: object
# 4200
# created_at                                      2020-05-02 13-45-52
# id_str                                          1256580670589145091
# text              rt eliezersalinasd inmenso porcentaje fallecid...
# user              {'id': 1367209680, 'id_str': '1367209680', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    Maracay
# country\r                                               venezuela\r
# day                                                      2020-05-02
# hour                                                             13
# Name: 4199, dtype: object
# 4300
# created_at                                      2020-05-02 22-44-27
# id_str                                          1256716209510178816
# text              rt drependiente así ve ignorancia amixes covid...
# user              {'id': 854201964044836864, 'id_str': '85420196...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Estado de México
# country\r                                                  méxico\r
# day                                                      2020-05-02
# hour                                                             22
# Name: 4299, dtype: object
# 4400
# created_at                                      2020-05-02 22-05-12
# id_str                                          1256706331911884801
# text              favor toma conciencia cuidate entorno covid19c...
# user              {'id': 892034616680493056, 'id_str': '89203461...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                             Metropolitana de Santiago, Chi
# country\r                                                   chile\r
# day                                                      2020-05-02
# hour                                                             22
# Name: 4399, dtype: object
# 4500
# created_at                                      2020-05-03 02-05-04
# id_str                                          1256766696347631622
# text              rt dw_espanol último coronavirus brasil segund...
# user              {'id': 200524059, 'id_str': '200524059', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                   Lanus, Bs. As.,ARGENTINA
# country\r                                               argentina\r
# day                                                      2020-05-03
# hour                                                             02
# Name: 4499, dtype: object
# 4600
# created_at                                      2020-05-03 04-43-49
# id_str                                          1256806647084863488
# text              rt rsalinascorona si exigimos cifras muertos n...
# user              {'id': 982709922994454531, 'id_str': '98270992...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                Comuna Colina R.M. Santiago
# country\r                                                       -\r
# day                                                      2020-05-03
# hour                                                             04
# Name: 4599, dtype: object
# 4700
# created_at                                      2020-05-02 14-30-18
# id_str                                          1256591852599488512
# text              rt naishka23 covid salga casas mayo salgan cor...
# user              {'id': 702977084524666880, 'id_str': '70297708...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       Arecibo, Puerto Rico
# country\r                                           united states\r
# day                                                      2020-05-02
# hour                                                             14
# Name: 4699, dtype: object
# 4800
# created_at                                      2020-05-03 00-35-02
# id_str                                          1256744038708977664
# text              rt simonlevymx prohibido pensar pandemia ayuda...
# user              {'id': 216092099, 'id_str': '216092099', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Puebla, México
# country\r                                                  méxico\r
# day                                                      2020-05-03
# hour                                                             00
# Name: 4799, dtype: object
# 4900
# created_at                                      2020-05-02 14-36-38
# id_str                                          1256593446414045184
# text              rt diariocorreo opinión coronavirus devela fra...
# user              {'id': 493496578, 'id_str': '493496578', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Lima_Perú
# country\r                                                    perú\r
# day                                                      2020-05-02
# hour                                                             14
# Name: 4899, dtype: object
# 5000
# created_at                                      2020-05-02 23-17-07
# id_str                                          1256724430342049794
# text                        cascabelito09 util favor covid19ecuador
# user              {'id': 22980356, 'id_str': '22980356', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Guayaquil
# country\r                                                 ecuador\r
# day                                                      2020-05-02
# hour                                                             23
# Name: 4999, dtype: object
# 5100
# created_at                                      2020-05-02 16-38-18
# id_str                                          1256624064837201921
# text              rt anguitaexe coronavirus arruinó q podría hab...
# user              {'id': 749884886, 'id_str': '749884886', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       EXO'rDIUM 27/04/17🇲🇽
# country\r                                                       -\r
# day                                                      2020-05-02
# hour                                                             16
# Name: 5099, dtype: object
# 5200
# created_at                                      2020-05-02 16-43-24
# id_str                                          1256625348286001153
# text              rt redmasnoticias salud 459 contagiados 7 fall...
# user              {'id': 866599625456799745, 'id_str': '86659962...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                   Colombia
# country\r                                                colombia\r
# day                                                      2020-05-02
# hour                                                             16
# Name: 5199, dtype: object
# 5300
# created_at                                      2020-05-02 08-01-17
# id_str                                          1256493953341370368
# text              covid19 mundo mexico alcanza 1972 muertes 2073...
# user              {'id': 501045616, 'id_str': '501045616', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                       Cuba
# country\r                                                    cuba\r
# day                                                      2020-05-02
# hour                                                             08
# Name: 5299, dtype: object
# 5400
# created_at                                      2020-05-02 23-46-40
# id_str                                          1256731866842968064
# text              rt jcvpositivo todoscontralamentiram medio d p...
# user              {'id': 1128739492947472387, 'id_str': '1128739...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                          Colpayo Argentina
# country\r                                               argentina\r
# day                                                      2020-05-02
# hour                                                             23
# Name: 5399, dtype: object
# 5500
# created_at                                      2020-05-02 11-13-12
# id_str                                          1256542250751995904
# text              dinero público empuja investigación covid19 ga...
# user              {'id': 409808586, 'id_str': '409808586', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                        Barriada filosófica
# country\r                                                       -\r
# day                                                      2020-05-02
# hour                                                             11
# Name: 5499, dtype: object
# 5600
# created_at                                      2020-05-03 00-15-00
# id_str                                          1256738997155454979
# text              rt cr_politico 1 abro hilo video hospital lasa...
# user              {'id': 87831391, 'id_str': '87831391', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                    Los Angeles, California
# country\r                                           united states\r
# day                                                      2020-05-03
# hour                                                             00
# Name: 5599, dtype: object
# 5700
# created_at                                      2020-05-03 00-41-23
# id_str                                          1256745636738797568
# text                                    malditos coronavid19 mamado
# user              {'id': 310475307, 'id_str': '310475307', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# ...
# user              {'id': 1085937210308902912, 'id_str': '1085937...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Venezuela
# country\r                                               venezuela\r
# day                                                      2020-05-31
# hour                                                             09
# Name: 105799, dtype: object
# 105900
# created_at                                      2020-06-01 05-46-47
# id_str                                          1267331741255172096
# text              rt wilmerguillen_ cierre 5ta temporada serie c...
# user              {'id': 607553959, 'id_str': '607553959', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                              Coatzacoalcos
# country\r                                                  méxico\r
# day                                                      2020-06-01
# hour                                                             05
# Name: 105899, dtype: object
# 106000
# created_at                                      2020-05-31 15-00-35
# id_str                                          1267108721760428034
# text              rt lasillarota empresa euphoria tramitó permis...
# user              {'id': 201050630, 'id_str': '201050630', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                       CDMX
# country\r                                                  méxico\r
# day                                                      2020-05-31
# hour                                                             15
# Name: 105999, dtype: object
# 106100
# created_at                                      2020-06-01 01-35-20
# id_str                                          1267268461828411403
# text              rt carlosgidib ética tiempos coronavirus aerom...
# user              {'id': 314027057, 'id_str': '314027057', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                         Cuernavaca Morelos
# country\r                                                  méxico\r
# day                                                      2020-06-01
# hour                                                             01
# Name: 106099, dtype: object
# 106200
# created_at                                      2020-05-31 06-32-46
# id_str                                          1266980925503610880
# text                                     chanttal_corona veo martes
# user              {'id': 855881575908560896, 'id_str': '85588157...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                               Morelia, Michoacán de Ocampo
# country\r                                                  méxico\r
# day                                                      2020-05-31
# hour                                                             06
# Name: 106199, dtype: object
# 106300
# created_at                                      2020-05-31 17-13-42
# id_str                                          1267142221637324800
# text              rt fernandopoyo1 buen día amigos país común mi...
# user              {'id': 80332389, 'id_str': '80332389', 'name':...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Argentina
# country\r                                               argentina\r
# day                                                      2020-05-31
# hour                                                             17
# Name: 106299, dtype: object
# 106400
# created_at                                      2020-05-31 12-49-11
# id_str                                          1267075653830160385
# text              blog jalguerrero inutilidad fármacos covid19 s...
# user              {'id': 627373578, 'id_str': '627373578', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                     Málaga
# country\r                                                  españa\r
# day                                                      2020-05-31
# hour                                                             12
# Name: 106399, dtype: object
# 106500
# created_at                                      2020-05-31 15-02-32
# id_str                                          1267109212481556481
# text              rt noticaribe plena pandemia hijo miguel torru...
# user              {'id': 1149165600, 'id_str': '1149165600', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    MEXICO
# country\r                                                  méxico\r
# day                                                      2020-05-31
# hour                                                             15
# Name: 106499, dtype: object
# 106600
# created_at                                      2020-05-31 23-55-07
# id_str                                          1267243241474158592
# text              rt lwthstbsl entienden plena pandemia aún así ...
# user              {'id': 322199980, 'id_str': '322199980', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                        No
# country\r                                                   norge\r
# day                                                      2020-05-31
# hour                                                             23
# Name: 106599, dtype: object
# 106700
# created_at                                      2020-06-01 01-16-00
# id_str                                          1267263596427386881
# text              rt fvrbulletproof pasando parece tan surrealis...
# user              {'id': 302648386, 'id_str': '302648386', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                       Viña del mar, Italia
# country\r                                                   chile\r
# day                                                      2020-06-01
# hour                                                             01
# Name: 106699, dtype: object
# 106800
# created_at                                      2020-05-31 21-59-31
# id_str                                          1267214149764952064
# text                  deadonarrivaal paso van salvar mundo pandemia
# user              {'id': 953124402664820737, 'id_str': '95312440...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             🏳️‍🌈 (she/her)
# country\r                                                  polska\r
# day                                                      2020-05-31
# hour                                                             21
# Name: 106799, dtype: object
# 106900
# created_at                                      2020-05-31 13-46-56
# id_str                                          1267090187114311682
# text              rt damarisfany caras vemos covid19 positivo as...
# user              {'id': 222299848, 'id_str': '222299848', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                               Gdl-CdMx-NY-CdMx-Mty-CdMx...
# country\r                                                       -\r
# day                                                      2020-05-31
# hour                                                             13
# Name: 106899, dtype: object
# 107000
# created_at                                      2020-06-01 02-44-26
# id_str                                          1267285851383439362
# text                                   marianfrancovip buena cogida
# user              {'id': 1250353447385198593, 'id_str': '1250353...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                Ecatepec de Morelos, México
# country\r                                                  méxico\r
# day                                                      2020-06-01
# hour                                                             02
# Name: 106999, dtype: object
# 107100
# created_at                                      2020-05-31 23-26-15
# id_str                                          1267235976927219712
# text              rt salcedoibiza pensando cosita si madrid gana...
# user              {'id': 1101276317813747712, 'id_str': '1101276...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Estados Unidos
# country\r                                           united states\r
# day                                                      2020-05-31
# hour                                                             23
# Name: 107099, dtype: object
# 107200
# created_at                                      2020-05-31 23-26-27
# id_str                                          1267236027246227458
# text              rt prensagrafica josé amílcar ramírez segundo ...
# user              {'id': 463845218, 'id_str': '463845218', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Centro América
# country\r                                               argentina\r
# day                                                      2020-05-31
# hour                                                             23
# Name: 107199, dtype: object
# 107300
# created_at                                      2020-05-31 19-16-48
# id_str                                          1267173200779149312
# text              rt colbolivariana entonces álvaro uribe vélez ...
# user              {'id': 3000694905, 'id_str': '3000694905', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                     Barranquilla, Colombia
# country\r                                                colombia\r
# day                                                      2020-05-31
# hour                                                             19
# Name: 107299, dtype: object
# 107400
# created_at                                      2020-05-31 17-14-36
# id_str                                          1267142448133951490
# text              dios entiendo año ahora volvió anonymous pande...
# user              {'id': 206937470, 'id_str': '206937470', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                    lg[b]t
# country\r                                             deutschland\r
# day                                                      2020-05-31
# hour                                                             17
# Name: 107399, dtype: object
# 107500
# created_at                                      2020-05-31 14-27-51
# id_str                                          1267100484143325186
# text              rt fedenaga 31052020 segundo comunicado fedena...
# user              {'id': 2557644894, 'id_str': '2557644894', 'na...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                                  Venezuela
# country\r                                               venezuela\r
# day                                                      2020-05-31
# hour                                                             14
# Name: 107499, dtype: object
# 107600
# created_at                                      2020-06-01 01-43-32
# id_str                                          1267270525421711360
# text              rt mauricioviramon razón autoridades vale madr...
# user              {'id': 460466995, 'id_str': '460466995', 'name...
# lang                                                             es
# favorite_count                                                  0.0
# retweet_count                                                   0.0
# quote_count                                                     0.0
# location                                             Sonora, México
# country\r                                                  méxico\r
# day                                                      2020-06-01
# hour                                                             01
# Name: 107599, dtype: object

# %%
df_tweets = pd.concat([df_tweets, df_emotions], axis=1)

# %%
df_tweets.to_csv(r"D:\covid research\output\step 3 output\2020-05-ES.csv")
